# %%
import psutil
import time

def increase_cpu_utilization(percentage, duration):
    """
    Increase CPU utilization to the specified percentage for the specified duration.
    """
    print(f"Increasing CPU utilization to {percentage}% for {duration} seconds...")
    while True:
        psutil.cpu_percent(percentage)
        time.sleep(0.1)

def increase_memory_utilization(memory_size_mb, duration):
    """
    Increase memory utilization by allocating memory_size_mb megabytes for the specified duration.
    """
    print(f"Increasing memory utilization by allocating {memory_size_mb} MB for {duration} seconds...")
    memory_alloc = bytearray(memory_size_mb * 1024 * 1024)
    time.sleep(duration)

if __name__ == "__main__":
    # Increase CPU utilization to 50% for 10 seconds
    increase_cpu_utilization(95, 10000000)

    # Increase memory utilization by allocating 100MB for 10 seconds
    increase_memory_utilization(300, 10000000)

# %%
# !pip install psutil
# Out:
# ...
#      |████████████████████████████████| 296kB 1.3MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 19.3.1; however, version 24.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import time

def heavy_computation():
    """
    Simulate a heavy computation task.
    """
    start_time = time.time()
    end_time = start_time + (2 * 60 * 60)  # Run for 2 hours

    while time.time() < end_time:
        # Perform heavy computation
        result = 0
        for i in range(10**7):
            result += i ** 2

        # Sleep for a short duration to avoid consuming all CPU resources
        time.sleep(0.1)

if __name__ == "__main__":
    heavy_computation()
