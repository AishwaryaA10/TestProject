# %%
# !pip install dtale
# Out:
# Collecting dtale
#   Downloading https://files.pythonhosted.org/packages/de/da/7f466cc6aedd4ae308423151269844f8c3ffedb12bfea5553f33298b92a6/dtale-3.11.0-py2.py3-none-any.whl (14.3MB)
#      |████████████████████████████████| 14.3MB 1.2MB/s eta 0:00:01
# Collecting dash; python_version > "3.7"
#   Downloading https://files.pythonhosted.org/packages/b0/68/781d0026a100106b64e4501c76621dfcd0d3c29a546094fcffaa73037a74/dash-2.16.1-py3-none-any.whl (10.2MB)
#      |████████████████████████████████| 10.2MB 44.6MB/s eta 0:00:01
# Collecting beautifulsoup4; python_version > "3.0"
#   Downloading https://files.pythonhosted.org/packages/b1/fe/e8c672695b37eecc5cbf43e1d0638d88d66ba3a44c4d321c796f4e59167f/beautifulsoup4-4.12.3-py3-none-any.whl (147kB)
#      |████████████████████████████████| 153kB 51.8MB/s eta 0:00:01
# Collecting numpy; python_version >= "3.0"
#   Downloading https://files.pythonhosted.org/packages/54/30/c2a907b9443cf42b90c17ad10c1e8fa801975f01cb9764f3f8eb8aea638b/numpy-1.26.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2MB)
#      |████████████████████████████████| 18.3MB 46.0MB/s eta 0:00:01
# Collecting flask-ngrok; python_version > "3.0"
#   Downloading https://files.pythonhosted.org/packages/af/6c/f54cb686ad1129e27d125d182f90f52b32f284e6c8df58c1bae54fa1adbc/flask_ngrok-0.0.25-py3-none-any.whl
# Collecting dash-daq
#   Downloading https://files.pythonhosted.org/packages/16/c1/9c6adfc3646990965a5b2ca073f579cc9c09d15553fcfcd83aefd1255494/dash_daq-0.5.0.tar.gz (642kB)
#      |████████████████████████████████| 645kB 33.0MB/s eta 0:00:01
# Collecting missingno
#   Downloading https://files.pythonhosted.org/packages/87/22/cd5cf999af21c2f97486622c551ac3d07361ced8125121e907f588ff5f24/missingno-0.5.2-py3-none-any.whl
# Collecting contourpy; python_version >= "3.9"
#   Downloading https://files.pythonhosted.org/packages/31/a2/2f12e3a6e45935ff694654b710961b03310b0e1ec997ee9f416d3c873f87/contourpy-1.2.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (304kB)
#      |████████████████████████████████| 307kB 34.2MB/s eta 0:00:01
# Collecting itsdangerous; python_version >= "3.7"
#   Downloading https://files.pythonhosted.org/packages/68/5f/447e04e828f47465eeab35b5d408b7ebaaaee207f48b7136c5a7267a30ae/itsdangerous-2.1.2-py3-none-any.whl
# Collecting openpyxl!=3.2.0b1; python_version >= "3.0"
#   Downloading https://files.pythonhosted.org/packages/6a/94/a59521de836ef0da54aaf50da6c4da8fb4072fb3053fa71f052fd9399e7a/openpyxl-3.1.2-py2.py3-none-any.whl (249kB)
#      |████████████████████████████████| 256kB 50.7MB/s eta 0:00:01
# Collecting xlrd
#   Downloading https://files.pythonhosted.org/packages/a6/0c/c2a72d51fe56e08a08acc85d13013558a2d793028ae7385448a6ccdfae64/xlrd-2.0.1-py2.py3-none-any.whl (96kB)
#      |████████████████████████████████| 102kB 15.9MB/s ta 0:00:01
# Collecting Flask<2.3; python_version >= "3.7"
#   Downloading https://files.pythonhosted.org/packages/9f/1a/8b6d48162861009d1e017a9740431c78d860809773b66cac220a11aa3310/Flask-2.2.5-py3-none-any.whl (101kB)
#      |████████████████████████████████| 102kB 14.4MB/s ta 0:00:01
# Collecting Flask-Compress
#   Downloading https://files.pythonhosted.org/packages/3f/d2/23fd656d38d4c896fa14371990b9978722c48a30d0edcf6b5f7054775a07/Flask_Compress-1.14-py3-none-any.whl
# Collecting cycler; python_version > "3.6"
#   Downloading https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl
# Collecting werkzeug; python_version > "3.7"
#   Downloading https://files.pythonhosted.org/packages/e3/23/c9843d7550092ae7ad380611c238f44afef66f58f76c1dab7dcf313e4339/werkzeug-3.0.2-py3-none-any.whl (226kB)
#      |████████████████████████████████| 235kB 32.6MB/s eta 0:00:01
# Collecting requests; python_version >= "3.7"
#   Downloading https://files.pythonhosted.org/packages/70/8e/0e2d847013cb52cd35b38c009bb167a1a26b2ce6cd6965bf26b47bc0bf44/requests-2.31.0-py3-none-any.whl (62kB)
#      |████████████████████████████████| 71kB 5.1MB/s  eta 0:00:01
# Collecting pandas
#   Downloading https://files.pythonhosted.org/packages/1a/5e/71bb0eef0dc543f7516d9ddeca9ee8dc98207043784e3f7e6c08b4a6b3d9/pandas-2.2.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0MB)
#      |████████████████████████████████| 13.0MB 44.4MB/s eta 0:00:01
# Collecting six
#   Downloading https://files.pythonhosted.org/packages/d9/5a/e7c31adbe875f2abbb91bd84cf2dc52d792b5a01506781dbcf25c91daf11/six-1.16.0-py2.py3-none-any.whl
# Collecting strsimpy
#   Downloading https://files.pythonhosted.org/packages/fc/90/bd55a4b18f4b75a76e32f444975d2c869d692eb23897d116d47122f88d1a/strsimpy-0.2.1-py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 6.9MB/s  eta 0:00:01
# Collecting xarray; python_version >= "3.0"
#   Downloading https://files.pythonhosted.org/packages/f7/fe/c4d15ac730b2bcdd530e4bc6491958c53237eb573dba4eec3ad31ff0519a/xarray-2024.3.0-py3-none-any.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 48.6MB/s eta 0:00:01
# Collecting lz4; python_version > "3.6"
#   Downloading https://files.pythonhosted.org/packages/10/39/baa1138796c410449ec1d8942cd8105c1ed41745e2b16f64dbe02ff10ee3/lz4-4.3.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3MB)
#      |████████████████████████████████| 1.3MB 32.9MB/s eta 0:00:01
# Collecting certifi; python_version > "3.0"
#   Downloading https://files.pythonhosted.org/packages/ba/06/a07f096c664aeb9f01624f858c3add0a4e913d6c96257acb4fce61e7de14/certifi-2024.2.2-py3-none-any.whl (163kB)
#      |████████████████████████████████| 163kB 53.3MB/s eta 0:00:01
# Collecting squarify
#   Downloading https://files.pythonhosted.org/packages/0b/2b/2e77c35326efec19819cd1d729540d4d235e6c2a3f37658288a363a67da5/squarify-0.4.3-py3-none-any.whl
# Collecting plotly; python_version >= "3.6"
#   Downloading https://files.pythonhosted.org/packages/00/4e/6258fc3b26f1f7abd1b2e75b1e9e4f12f13584136e2e1549f995ff4c6b7b/plotly-5.20.0-py3-none-any.whl (15.7MB)
#      |████████████████████████████████| 15.7MB 43.6MB/s eta 0:00:01
# Collecting matplotlib; python_version >= "3.9"
#   Downloading https://files.pythonhosted.org/packages/5e/2c/513395a63a9e1124a5648addbf73be23cc603f955af026b04416da98dc96/matplotlib-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6MB)
#      |████████████████████████████████| 11.6MB 32.9MB/s eta 0:00:01
# Collecting networkx; python_version > "3.8"
#   Downloading https://files.pythonhosted.org/packages/d5/f0/8fbc882ca80cf077f1b246c0e3c3465f7f415439bdea6b899f6b19f61f70/networkx-3.2.1-py3-none-any.whl (1.6MB)
#      |████████████████████████████████| 1.6MB 48.5MB/s eta 0:00:01
# Collecting scikit-learn; python_version > "3.8"
#   Downloading https://files.pythonhosted.org/packages/f0/e8/c95689d74c61f558e9e7d4ef21173811dc2ae303d1307090f85bf5a3b70b/scikit_learn-1.4.1.post1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2MB)
#      |████████████████████████████████| 12.2MB 42.9MB/s eta 0:00:01
# Collecting et-xmlfile; python_version >= "3.6"
#   Downloading https://files.pythonhosted.org/packages/96/c2/3dd434b0108730014f1b96fd286040dc3bcb70066346f7e01ec2ac95865f/et_xmlfile-1.1.0-py3-none-any.whl
# Collecting seaborn; python_version > "3.7"
#   Downloading https://files.pythonhosted.org/packages/83/11/00d3c3dfc25ad54e731d91449895a79e4bf2384dc3ac01809010ba88f6d5/seaborn-0.13.2-py3-none-any.whl (294kB)
#      |████████████████████████████████| 296kB 45.5MB/s eta 0:00:01
# Collecting future>=0.14.0
#   Downloading https://files.pythonhosted.org/packages/da/71/ae30dadffc90b9006d77af76b393cb9dfbfc9629f339fc1574a1c52e6806/future-1.0.0-py3-none-any.whl (491kB)
#      |████████████████████████████████| 491kB 39.1MB/s eta 0:00:01
# Collecting kaleido
#   Downloading https://files.pythonhosted.org/packages/ae/b3/a0f0f4faac229b0011d8c4a7ee6da7c2dca0b6fd08039c95920846f23ca4/kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9MB)
#      |█▏                              | 3.0MB 45.0MB/s eta 0:00:02
#      |████████████████████████████████| 79.9MB 215kB/s  eta 0:00:01     |████████▋                       | 21.6MB 14.2MB/s eta 0:00:05     |███████████████████████████▊    | 69.1MB 13.0MB/s eta 0:00:01
# Collecting dash-bootstrap-components<=1.3.1; python_version > "3.6"
#   Downloading https://files.pythonhosted.org/packages/81/51/ef076f364c6ecdc6abf8c9aa73c4acd1c44fed523c9a9da20a41ab2fd4d8/dash_bootstrap_components-1.3.1-py3-none-any.whl (219kB)
#      |████████████████████████████████| 225kB 11.4MB/s eta 0:00:01
# Collecting dash-colorscales
#   Downloading https://files.pythonhosted.org/packages/d5/24/de9318acd52989d77135a8497c8be536442b725473684ed4e1ab999b2051/dash_colorscales-0.0.4.tar.gz (62kB)
#      |████████████████████████████████| 71kB 7.1MB/s  eta 0:00:01
# Collecting scipy!=1.12.0rc1; python_version >= "3.9"
#   Downloading https://files.pythonhosted.org/packages/c6/ba/a778e6c0020d728c119b0379805a357135fe8c9bc87fdb7e0750ca11319f/scipy-1.13.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6MB)
#      |████████████████████████████████| 38.6MB 8.6MB/s eta 0:00:01
# Collecting statsmodels; python_version > "3.7"
#   Downloading https://files.pythonhosted.org/packages/a9/70/ead31bc6c1592a5237190994cc7023c7a2b79be287d0b3eb883a48019db0/statsmodels-0.14.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8MB)
#      |████████████████████████████████| 10.8MB 6.6MB/s eta 0:00:01
# Collecting dash-core-components==2.0.0
#   Downloading https://files.pythonhosted.org/packages/00/9e/a29f726e84e531a36d56cff187e61d8c96d2cc253c5bcef9a7695acb7e6a/dash_core_components-2.0.0-py3-none-any.whl
# Collecting setuptools
#   Downloading https://files.pythonhosted.org/packages/92/e1/1c8bb3420105e70bdf357d57dd5567202b4ef8d27f810e98bb962d950834/setuptools-69.2.0-py3-none-any.whl (821kB)
#      |████████████████████████████████| 829kB 10.8MB/s eta 0:00:01
# Collecting importlib-metadata
#   Downloading https://files.pythonhosted.org/packages/2d/0a/679461c511447ffaf176567d5c496d1de27cbe34a87df6677d7171b2fbd4/importlib_metadata-7.1.0-py3-none-any.whl
# Collecting retrying
#   Downloading https://files.pythonhosted.org/packages/8f/04/9e36f28be4c0532c0e9207ff9dc01fb13a2b0eb036476a213b0000837d0e/retrying-1.3.4-py3-none-any.whl
# Collecting typing-extensions>=4.1.1
#   Downloading https://files.pythonhosted.org/packages/01/f3/936e209267d6ef7510322191003885de524fc48d1b43269810cd589ceaf5/typing_extensions-4.11.0-py3-none-any.whl
# Collecting nest-asyncio
#   Downloading https://files.pythonhosted.org/packages/a0/c4/c2971a3ba4c6103a3d10c4b0f24f461ddc027f0f09763220cf35ca1401b3/nest_asyncio-1.6.0-py3-none-any.whl
# Collecting dash-html-components==2.0.0
#   Downloading https://files.pythonhosted.org/packages/75/65/1b16b853844ef59b2742a7de74a598f376ac0ab581f0dcc34db294e5c90e/dash_html_components-2.0.0-py3-none-any.whl
# Collecting dash-table==5.0.0
#   Downloading https://files.pythonhosted.org/packages/da/ce/43f77dc8e7bbad02a9f88d07bf794eaf68359df756a28bb9f2f78e255bb1/dash_table-5.0.0-py3-none-any.whl
# Collecting soupsieve>1.2
#   Downloading https://files.pythonhosted.org/packages/4c/f3/038b302fdfbe3be7da016777069f26ceefe11a681055ea1f7817546508e3/soupsieve-2.5-py3-none-any.whl
# Collecting Jinja2>=3.0
#   Downloading https://files.pythonhosted.org/packages/30/6d/6de6be2d02603ab56e72997708809e8a5b0fbfee080735109b40a3564843/Jinja2-3.1.3-py3-none-any.whl (133kB)
#      |████████████████████████████████| 143kB 10.1MB/s eta 0:00:01
# Collecting click>=8.0
#   Downloading https://files.pythonhosted.org/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl (97kB)
#      |████████████████████████████████| 102kB 8.2MB/s eta 0:00:01
# Collecting brotli; platform_python_implementation != "PyPy"
#   Downloading https://files.pythonhosted.org/packages/e2/e6/4a730f6e5b5d538e92d09bc51bf69119914f29a222f9e1d65ae4abb27a4e/Brotli-1.1.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (2.8MB)
#      |████████████████████████████████| 2.8MB 9.6MB/s eta 0:00:01
# Collecting MarkupSafe>=2.1.1
#   Downloading https://files.pythonhosted.org/packages/5f/5a/360da85076688755ea0cceb92472923086993e86b5613bbae9fbc14136b0/MarkupSafe-2.1.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Collecting urllib3<3,>=1.21.1
#   Downloading https://files.pythonhosted.org/packages/a2/73/a68704750a7679d0b6d3ad7aa8d4da8e14e151ae82e6fee774e6e0d05ec8/urllib3-2.2.1-py3-none-any.whl (121kB)
#      |████████████████████████████████| 122kB 12.1MB/s eta 0:00:01
# Collecting idna<4,>=2.5
#   Downloading https://files.pythonhosted.org/packages/c2/e7/a82b05cf63a603df6e68d59ae6a68bf5064484a0718ea5033660af4b54a9/idna-3.6-py3-none-any.whl (61kB)
#      |████████████████████████████████| 71kB 7.4MB/s  eta 0:00:01
# Collecting charset-normalizer<4,>=2
#   Downloading https://files.pythonhosted.org/packages/98/69/5d8751b4b670d623aa7a47bef061d69c279e9f922f6705147983aa76c3ce/charset_normalizer-3.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142kB)
#      |████████████████████████████████| 143kB 11.1MB/s eta 0:00:01
# Collecting pytz>=2020.1
#   Downloading https://files.pythonhosted.org/packages/9c/3d/a121f284241f08268b21359bd425f7d4825cffc5ac5cd0e1b3d82ffd2b10/pytz-2024.1-py2.py3-none-any.whl (505kB)
#      |████████████████████████████████| 512kB 11.1MB/s eta 0:00:01
# Collecting python-dateutil>=2.8.2
#   Downloading https://files.pythonhosted.org/packages/ec/57/56b9bcc3c9c6a792fcbaf139543cee77261f3651ca9da0c93f5c1221264b/python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229kB)
#      |████████████████████████████████| 235kB 10.5MB/s eta 0:00:01
# Collecting tzdata>=2022.7
#   Downloading https://files.pythonhosted.org/packages/65/58/f9c9e6be752e9fcb8b6a0ee9fb87e6e7a1f6bcab2cdc73f02bb7ba91ada0/tzdata-2024.1-py2.py3-none-any.whl (345kB)
#      |████████████████████████████████| 348kB 11.2MB/s eta 0:00:01
# Collecting packaging>=22
#   Downloading https://files.pythonhosted.org/packages/49/df/1fceb2f8900f8639e278b056416d49134fb8d84c5942ffaa01ad34782422/packaging-24.0-py3-none-any.whl (53kB)
#      |████████████████████████████████| 61kB 6.8MB/s  eta 0:00:01
# Collecting tenacity>=6.2.0
#   Downloading https://files.pythonhosted.org/packages/f4/f1/990741d5bb2487d529d20a433210ffa136a367751e454214013b441c4575/tenacity-8.2.3-py3-none-any.whl
# Collecting pillow>=8
#   Downloading https://files.pythonhosted.org/packages/15/5c/2e16159554296a10017bfad367d495909f863abf7ea506f24fff8e6799b3/pillow-10.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4MB)
#      |████████████████████████████████| 4.4MB 11.8MB/s eta 0:00:01
# Collecting fonttools>=4.22.0
#   Downloading https://files.pythonhosted.org/packages/8b/c6/636f008104908a93b80419f756be755bb91df4b8a0c88d5158bb52c82c3a/fonttools-4.51.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6MB)
#      |████████████████████████████████| 4.6MB 7.6MB/s eta 0:00:01
# Collecting pyparsing>=2.3.1
#   Downloading https://files.pythonhosted.org/packages/9d/ea/6d76df31432a0e6fdf81681a895f009a4bb47b3c39036db3e1b528191d52/pyparsing-3.1.2-py3-none-any.whl (103kB)
#      |████████████████████████████████| 112kB 6.7MB/s eta 0:00:01
# Collecting importlib-resources>=3.2.0; python_version < "3.10"
#   Downloading https://files.pythonhosted.org/packages/75/06/4df55e1b7b112d183f65db9503bff189e97179b256e1ea450a3c365241e0/importlib_resources-6.4.0-py3-none-any.whl
# Collecting kiwisolver>=1.3.1
#   Downloading https://files.pythonhosted.org/packages/c0/a8/841594f11d0b88d8aeb26991bc4dac38baa909dc58d0c4262a4f7893bcbf/kiwisolver-1.4.5-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6MB)
#      |████████████████████████████████| 1.6MB 6.0MB/s eta 0:00:01
# Collecting threadpoolctl>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/1e/84/ccd9b08653022b7785b6e3ee070ffb2825841e0dc119be22f0840b2b35cb/threadpoolctl-3.4.0-py3-none-any.whl
# Collecting joblib>=1.2.0
#   Downloading https://files.pythonhosted.org/packages/10/40/d551139c85db202f1f384ba8bcf96aca2f329440a844f924c8a0040b6d02/joblib-1.3.2-py3-none-any.whl (302kB)
#      |████████████████████████████████| 307kB 6.5MB/s eta 0:00:01
# Collecting patsy>=0.5.4
#   Downloading https://files.pythonhosted.org/packages/43/f3/1d311a09c34f14f5973bb0bb0dc3a6e007e1eda90b5492d082689936ca51/patsy-0.5.6-py2.py3-none-any.whl (233kB)
#      |████████████████████████████████| 235kB 6.6MB/s eta 0:00:01
# Collecting zipp>=0.5
#   Downloading https://files.pythonhosted.org/packages/c2/0a/ba9d0ee9536d3ef73a3448e931776e658b36f128d344e175bc32b092a8bf/zipp-3.18.1-py3-none-any.whl
# Building wheels for collected packages: dash-daq, dash-colorscales
#   Building wheel for dash-daq (setup.py) ... done
#   Created wheel for dash-daq: filename=dash_daq-0.5.0-cp39-none-any.whl size=669696 sha256=e8cc42668e576ea314afd887152fe913a47c056c57526536d26baabdceeb79ff
#   Stored in directory: /home/mosaic-ai/.cache/pip/wheels/1c/9c/f7/84731716eaa9fc952cdbdd1f87df3ca9b8805c317c609efcd6
#   Building wheel for dash-colorscales (setup.py) ... done
#   Created wheel for dash-colorscales: filename=dash_colorscales-0.0.4-cp39-none-any.whl size=62568 sha256=156041e9038a7009fabe1bb3b15b0fa0ab325385459a986f8383d9c3dd64f302
#   Stored in directory: /home/mosaic-ai/.cache/pip/wheels/0e/4a/1c/3490cfe6a59299b06917af6626a969c8fb7caead39b2d74cf2
# Successfully built dash-daq dash-colorscales
# ERROR: refractml 1.0.3 has requirement cloudpickle==1.6.0, but you'll have cloudpickle 2.2.1 which is incompatible.
# ERROR: refractml 1.0.3 has requirement PyYAML==6.0, but you'll have pyyaml 6.0.1 which is incompatible.
# ERROR: refractml 1.0.3 has requirement urllib3==1.26.15, but you'll have urllib3 2.2.1 which is incompatible.
# ERROR: refractio 2.1.5.2 has requirement pandas==2.0.0, but you'll have pandas 2.2.1 which is incompatible.
# ERROR: mosaic-utils 1.0.2 has requirement scikit-learn==1.2.1; python_version >= "3.8", but you'll have scikit-learn 1.4.1.post1 which is incompatible.
# ERROR: mlflow 2.6.0 has requirement importlib-metadata!=4.7.0,<7,>=3.7.0, but you'll have importlib-metadata 7.1.0 which is incompatible.
# ERROR: mlflow 2.6.0 has requirement packaging<24, but you'll have packaging 24.0 which is incompatible.
# ERROR: mlflow 2.6.0 has requirement pytz<2024, but you'll have pytz 2024.1 which is incompatible.
# ERROR: openapi-schema-validator 0.6.2 has requirement jsonschema<5.0.0,>=4.19.1, but you'll have jsonschema 4.19.0 which is incompatible.
# ERROR: mosaic-ai-serving 1.0.0 has requirement Flask==2.1.1; python_version >= "3.7", but you'll have flask 2.2.5 which is incompatible.
# ERROR: mosaic-ai-serving 1.0.0 has requirement itsdangerous==2.0.1, but you'll have itsdangerous 2.1.2 which is incompatible.
# ERROR: mosaic-ai-serving 1.0.0 has requirement Jinja2==3.0.3, but you'll have jinja2 3.1.3 which is incompatible.
# ERROR: mosaic-ai-serving 1.0.0 has requirement matplotlib==3.6.0; python_version >= "3.8", but you'll have matplotlib 3.8.4 which is incompatible.
# ERROR: mosaic-ai-client 1.0.0 has requirement matplotlib==3.1.1, but you'll have matplotlib 3.8.4 which is incompatible.
# ERROR: jupyterlab 3.2.4 has requirement jupyter-server~=1.4, but you'll have jupyter-server 2.7.3 which is incompatible.
# ERROR: jsonschema-path 0.3.2 has requirement referencing<0.32.0,>=0.28.0, but you'll have referencing 0.33.0 which is incompatible.
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests, dash-core-components, setuptools, zipp, importlib-metadata, six, retrying, MarkupSafe, werkzeug, typing-extensions, nest-asyncio, tenacity, packaging, plotly, dash-html-components, dash-table, Jinja2, click, itsdangerous, Flask, dash, soupsieve, beautifulsoup4, numpy, flask-ngrok, dash-daq, pytz, python-dateutil, tzdata, pandas, cycler, contourpy, pillow, fonttools, pyparsing, importlib-resources, kiwisolver, matplotlib, seaborn, scipy, missingno, et-xmlfile, openpyxl, xlrd, brotli, Flask-Compress, strsimpy, xarray, lz4, squarify, networkx, threadpoolctl, joblib, scikit-learn, future, kaleido, dash-bootstrap-components, dash-colorscales, patsy, statsmodels, dtale

# %%
import dtale
import pandas as pd

df = pd.DataFrame([dict(a=1,b=2,c=3)])

# Assigning a reference to a running D-Tale process
d = dtale.show(df)

# Accessing data associated with D-Tale process
tmp = d.data.copy()
tmp['d'] = 4

# Altering data associated with D-Tale process
# FYI: this will clear any front-end settings you have at the time for this process (filter, sorts, formatting)
d.data = tmp

# Shutting down D-Tale process
d.kill()

# using Python's `webbrowser` package it will try and open your server's default browser to this process
d.open_browser()

# There is also some helpful metadata about the process
d._data_id  # the process's data identifier
d._url  # the url to access the process

d2 = dtale.get_instance(d._data_id)  # returns a new reference to the instance running at that data_id

dtale.instances()  # prints a list of all ids & urls of running D-Tale sessions
# Out:
# 2024-04-08 05:39:27,561 - INFO     - Shutdown complete
# To gain access to an instance object simply pass the value from 'ID' to dtale.get_instance(ID)
#
# ID Name                                                                                    URL
#  1      http://jy-d29ee55f-8558-48ee-8a18-c3b2f1dd581d-swapnilwarulefosforc:40000/dtale/main/1
#         http://jy-d29ee55f-8558-48ee-8a18-c3b2f1dd581d-swapnilwarulefosforc:40000/dtale/main/1
