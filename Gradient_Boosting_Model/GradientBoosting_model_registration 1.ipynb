# %%
# !pip install scikit-learn==1.4.2
# !pip install numpy==1.26.4
# Out:
# Collecting scikit-learn==1.4.2
#   Using cached scikit_learn-1.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting numpy>=1.19.5 (from scikit-learn==1.4.2)
#   Using cached numpy-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting scipy>=1.6.0 (from scikit-learn==1.4.2)
#   Using cached scipy-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting joblib>=1.2.0 (from scikit-learn==1.4.2)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn==1.4.2)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached numpy-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
# Using cached scipy-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (40.6 MB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, numpy, joblib, scipy, scikit-learn
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fosforml 1.2.0a0 requires scikit-learn==1.3.2, but you have scikit-learn 1.4.2 which is incompatible.
# snowflake-ml-python 1.5.1 requires numpy<2,>=1.23, but you have numpy 2.2.2 which is incompatible.
# snowflake-ml-python 1.5.1 requires scikit-learn<1.4,>=1.2.1, but you have scikit-learn 1.4.2 which is incompatible.
# Successfully installed joblib-1.4.2 numpy-2.2.2 scikit-learn-1.4.2 scipy-1.15.1 threadpoolctl-3.5.0
# WARNING: Target directory /tmp/pip_packages/threadpoolctl.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/threadpoolctl-3.5.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/__pycache__ already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/numpy-2.2.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/numpy already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/numpy.libs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/joblib already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/joblib-1.4.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/scipy already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/scipy.libs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/scipy-1.15.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/sklearn already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/scikit_learn.libs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/scikit_learn-1.4.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /tmp/pip_packages/bin already exists. Specify --upgrade to force replacement.
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 161.7 MB/s eta 0:00:00
# Installing collected packages: numpy

# %%
from fosforml.model_manager.snowflakesession import get_session
session = get_session()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from fosforml.model_manager.snowflakesession import get_session
#       2 session = get_session()
#
# File /opt/conda/lib/python3.10/site-packages/fosforml/__init__.py:3
#       1 # -*- coding: utf-8 -*-
# ----> 3 from .api import register_model
#       5 from .decorators import scoring_func
#       7 __all__ = [
#       8     'register_model'
#       9 ]
#
# File /opt/conda/lib/python3.10/site-packages/fosforml/api.py:2
#       1 # -*- coding: utf-8 -*-
# ----> 2 from .model_manager import ModelRegistry
#       3 from fosforml.constants import ModelFlavours
#       4 from fosforml.utils import generate_model_name, validate_datasets_for_sf, validate_privileges
#
# File /opt/conda/lib/python3.10/site-packages/fosforml/model_manager/__init__.py:2
#       1 from .snowflakesession import snowflakesession
# ----> 2 from .model_registry import ModelRegistry
#       3 from .utilities import DatasetManager, Metadata
#       4 from .model_metrics import Classification, Regression
#
# File /opt/conda/lib/python3.10/site-packages/fosforml/model_manager/model_registry.py:1
# ----> 1 from snowflake.ml.registry import Registry
#       2 from .snowflakesession import snowflakesession as SnowflakeSession
#       3 from .utilities import DatasetManager, Metadata
#
# File /opt/conda/lib/python3.10/site-packages/snowflake/ml/registry/__init__.py:1
# ----> 1 from snowflake.ml.registry.registry import Registry
#       3 __all__ = ["Registry"]
#
# File /opt/conda/lib/python3.10/site-packages/snowflake/ml/registry/registry.py:8
#       6 from snowflake.ml._internal import telemetry
#       7 from snowflake.ml._internal.utils import sql_identifier
# ----> 8 from snowflake.ml.model import (
#       9     Model,
#      10     ModelVersion,
#      11     model_signature,
#      12     type_hints as model_types,
#      13 )
#      14 from snowflake.ml.registry._manager import model_manager
#      15 from snowflake.snowpark import session
#
# File /opt/conda/lib/python3.10/site-packages/snowflake/ml/model/__init__.py:1
# ----> 1 from snowflake.ml.model._client.model.model_impl import Model
#       2 from snowflake.ml.model._client.model.model_version_impl import ExportMode, ModelVersion
#       3 from snowflake.ml.model.models.huggingface_pipeline import HuggingFacePipelineModel
#
# File /opt/conda/lib/python3.10/site-packages/snowflake/ml/model/_client/model/model_impl.py:7
#       5 from snowflake.ml._internal import telemetry
#       6 from snowflake.ml._internal.utils import sql_identifier
# ----> 7 from snowflake.ml.model._client.model import model_version_impl
#       8 from snowflake.ml.model._client.ops import model_ops
#      10 _TELEMETRY_PROJECT = "MLOps"
#
# File /opt/conda/lib/python3.10/site-packages/snowflake/ml/model/_client/model/model_version_impl.py:12
#      10 from snowflake.ml._internal.utils import sql_identifier
#      11 from snowflake.ml.model import type_hints as model_types
# ---> 12 from snowflake.ml.model._client.ops import metadata_ops, model_ops
#      13 from snowflake.ml.model._model_composer import model_composer
#      14 from snowflake.ml.model._model_composer.model_manifest import model_manifest_schema
#
# File /opt/conda/lib/python3.10/site-packages/snowflake/ml/model/_client/ops/model_ops.py:9
#       6 import yaml
#       8 from snowflake.ml._internal.utils import identifier, sql_identifier
# ----> 9 from snowflake.ml.model import model_signature, type_hints
#      10 from snowflake.ml.model._client.ops import metadata_ops
#      11 from snowflake.ml.model._client.sql import (
#      12     model as model_sql,
#      13     model_version as model_version_sql,
#      14     stage as stage_sql,
#      15     tag as tag_sql,
#      16 )
#
# File /opt/conda/lib/python3.10/site-packages/snowflake/ml/model/model_signature.py:30
#      28 from snowflake.ml._internal.utils import formatting, identifier, sql_identifier
#      29 from snowflake.ml.model import type_hints as model_types
# ---> 30 from snowflake.ml.model._signatures import (
#      31     base_handler,
#      32     builtins_handler as builtins_handler,
#      33     core,
#      34     numpy_handler,
#      35     pandas_handler,
#      36     pytorch_handler,
#      37     snowpark_handler,
#      38     tensorflow_handler,
#      39     utils,
#      40 )
#      42 DataType = core.DataType
#      43 BaseFeatureSpec = core.BaseFeatureSpec
#
# File /opt/conda/lib/python3.10/site-packages/snowflake/ml/model/_signatures/pytorch_handler.py:8
#       5 import pandas as pd
#       6 from typing_extensions import TypeGuard
# ----> 8 from snowflake.ml._internal import type_utils
#       9 from snowflake.ml._internal.exceptions import (
#      10     error_codes,
#      11     exceptions as snowml_exceptions,
#      12 )
#      13 from snowflake.ml.model import type_hints as model_types
#
# File /opt/conda/lib/python3.10/site-packages/snowflake/ml/_internal/type_utils.py:69
#      65         except ValueError:
#      66             return False
# ---> 69 LiteralNDArrayType = Union[npt.NDArray[np.int_], npt.NDArray[np.float_], npt.NDArray[np.str_], npt.NDArray[np.bool_]]
#
# File /tmp/pip_packages/numpy/__init__.py:400, in __getattr__(attr)
#     397     raise AttributeError(__former_attrs__[attr], name=None)
#     399 if attr in __expired_attributes__:
# --> 400     raise AttributeError(
#     401         f"`np.{attr}` was removed in the NumPy 2.0 release. "
#     402         f"{__expired_attributes__[attr]}",
#     403         name=None
#     404     )
#     406 if attr == "chararray":
#     407     warnings.warn(
#     408         "`np.chararray` is deprecated and will be removed from "
#     409         "the main namespace in the future. Use an array with a string "
#     410         "or bytes dtype instead.", DeprecationWarning, stacklevel=2)
#
# AttributeError: `np.float_` was removed in the NumPy 2.0 release. Use `np.float64` instead.

# %%
import pandas as pd
import numpy as np
from fosforml import register_model

# %%
# load the iris dataset as an example 
from sklearn.datasets import load_iris 
iris= load_iris() 
iris.keys()

dict_keys=(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
iris= pd.DataFrame(
    data = np.c_[iris['data'], iris['target']],
    columns= iris['feature_names'] + ['target']
    )
iris.columns = ['SEPAL_LENGTH', 'SEPAL_WIDTH', 'PETAL_LENGTH', 'PETAL_WIDTH', 'TARGET']
iris.head(10)
# Out:
#    SEPAL_LENGTH  SEPAL_WIDTH  PETAL_LENGTH  PETAL_WIDTH  TARGET
# 0           5.1          3.5           1.4          0.2     0.0
# 1           4.9          3.0           1.4          0.2     0.0
# 2           4.7          3.2           1.3          0.2     0.0
# 3           4.6          3.1           1.5          0.2     0.0
# 4           5.0          3.6           1.4          0.2     0.0
# 5           5.4          3.9           1.7          0.4     0.0
# 6           4.6          3.4           1.4          0.3     0.0
# 7           5.0          3.4           1.5          0.2     0.0
# 8           4.4          2.9           1.4          0.2     0.0
# 9           4.9          3.1           1.5          0.1     0.0

# %%
species = []

for i in range(len(iris['TARGET'])):
    if iris['TARGET'][i] == 0:
        species.append("setosa")
    elif iris['TARGET'][i] == 1:
        species.append('versicolor')
    else:
        species.append('virginica')


iris['SPECIES'] = species

iris
# Out:
#      SEPAL_LENGTH  SEPAL_WIDTH  PETAL_LENGTH  PETAL_WIDTH  TARGET    SPECIES
# 0             5.1          3.5           1.4          0.2     0.0     setosa
# 1             4.9          3.0           1.4          0.2     0.0     setosa
# 2             4.7          3.2           1.3          0.2     0.0     setosa
# 3             4.6          3.1           1.5          0.2     0.0     setosa
# 4             5.0          3.6           1.4          0.2     0.0     setosa
# ..            ...          ...           ...          ...     ...        ...
# 145           6.7          3.0           5.2          2.3     2.0  virginica
# 146           6.3          2.5           5.0          1.9     2.0  virginica
# 147           6.5          3.0           5.2          2.0     2.0  virginica
# 148           6.2          3.4           5.4          2.3     2.0  virginica
# 149           5.9          3.0           5.1          1.8     2.0  virginica
#
# [150 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split

# Droping the target and species since we only need the measurements
X = iris.drop(['TARGET','SPECIES'], axis=1)

# converting into numpy array and assigning petal length and petal width
# X = X.to_numpy()[:, (2,3)]
y = iris['TARGET']

# Splitting into train and test
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.5, random_state=42)

# %%
from sklearn.ensemble import GradientBoostingClassifier
# Initialize and train the XGBoost classifier
model = GradientBoostingClassifier()
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# %%
y_train = y_train.to_frame()
y_test = y_test.to_frame()
y_pred = pd.DataFrame(y_pred, columns=["PREDICTION"])

# %%
register_model(
    model_obj=model, 
    session=session,
    x_train=X_train,
    y_train=y_train,
    x_test=X_test,
    y_test=y_test,
    y_pred=y_pred,
    source="Notebook",
    dataset_name="IRIS_DATASET",
    dataset_source="Snowflake",
    name="GradientBoostingClassifier_test_01",
    description=" Classification Model",
    flavour="sklearn",
    model_type="classification",
    conda_dependencies=["scikit-learn==1.4.2"]
)
# Out:
# Calculating build time metrics
#
# Progress: ██████████████                                                         20.0%
# Calculating build time metrics
#
# Progress: ████████████████████████████                                           40.0%
# The version of package 'scikit-learn' in the local environment is 1.3.2, which does not fit the criteria for the requirement 'scikit-learn<1.4'. Your UDF might not work when the package version is different between the server and your local environment.
# DataFrame.flatten() is deprecated since 0.7.0. Use `DataFrame.join_table_function()` instead.
# The version of package 'scikit-learn' in the local environment is 1.3.2, which does not fit the criteria for the requirement 'scikit-learn<1.4'. Your UDF might not work when the package version is different between the server and your local environment.
# The version of package 'scikit-learn' in the local environment is 1.3.2, which does not fit the criteria for the requirement 'scikit-learn<1.4'. Your UDF might not work when the package version is different between the server and your local environment.
# Calculating build time metrics
#
# Progress: ██████████████████████████████████████████                             60.0%
# Calculating build time metrics
#
# Progress: ████████████████████████████████████████████████████████               80.0%
# Calculating build time metrics
#
# Progress: ██████████████████████████████████████████████████████████████████████ 100.0%
# "Failed to register model 'MODEL_D5B4AEDB_BAB8_4D5A_80CC_FA0339D03677_FDC_GRADIENTBOOSTINGCLASSIFIER_TEST_01'. (1300) (1304): 01ba08eb-0412-ca7f-0072-f30316a00926: 100357 (P0000): Python Interpreter Error:\nModuleNotFoundError: No module named 'sklearn.ensemble._gb_losses' in function CreateModule-d60c1a63-db77-42bf-9d0d-e64403e9e78d with handler predict.infer"

# %%
import sklearn 
sklearn.__version__
# Out:
# '1.3.2'
