# %%
from snowflake.snowpark.session import Session

connection_params = {'user': "REFRACT.FOSFOR@LNTINFOTECH.COM", 'password': "Password321", 'account':"fya62509.us-east-1", 'role':"FOSFOR_REFRACT", 'warehouse': "FOSFOR_REFRACT"}

session = Session.builder.configs(connection_params).create()
data = session.sql("SHOW DATABASES;").collect()
print(data)
session.close()
# Out:
# [Row(created_on=datetime.datetime(2022, 1, 17, 4, 54, 13, 802000, tzinfo=<StaticTzInfo 'Etc/UTC'>), name='FOSFOR_REFRACT', is_default='N', is_current='N', origin='', owner='ACCOUNTADMIN', comment='DB for Refract', options='', retention_time='1', kind='STANDARD', budget=None, owner_role_type='ROLE'), Row(created_on=datetime.datetime(2022, 11, 14, 11, 4, 12, 720000, tzinfo=<StaticTzInfo 'Etc/UTC'>), name='REFRACT_SNOWFLAKE_INTEGRATION', is_default='N', is_current='N', origin='', owner='FOSFOR_REFRACT', comment='This database contains stored procedures, UDFs, tables which are required for integrating refract with Snowflake. This integration is focused on 1)pushing the execution to snowflake and 2)create an APP marketplace.', options='', retention_time='1', kind='STANDARD', budget=None, owner_role_type='ROLE'), Row(created_on=datetime.datetime(2021, 11, 29, 12, 52, 40, 59000, tzinfo=<StaticTzInfo 'Etc/UTC'>), name='SNOWFLAKE', is_default='N', is_current='N', origin='SNOWFLAKE.ACCOUNT_USAGE', owner='', comment='', options='', retention_time='0', kind='APPLICATION', budget=None, owner_role_type=''), Row(created_on=datetime.datetime(2023, 12, 4, 9, 16, 33, 710000, tzinfo=<StaticTzInfo 'Etc/UTC'>), name='SNOWFLAKE$GDS', is_default='N', is_current='N', origin='', owner='AUTO_FULFILLMENT_EXECUTOR', comment='', options='', retention_time='1', kind='STANDARD', budget=None, owner_role_type='ROLE'), Row(created_on=datetime.datetime(2022, 7, 3, 10, 42, 29, 737000, tzinfo=<StaticTzInfo 'Etc/UTC'>), name='SNOWFLAKE_SAMPLE_DATA', is_default='N', is_current='N', origin='SFSALESSHARED.SFC_SAMPLES_AWS_US_EAST_1_2.SAMPLE_DATA', owner='ACCOUNTADMIN', comment='', options='', retention_time='0', kind='IMPORTED DATABASE', budget=None, owner_role_type='ROLE')]

# %%
df1 = session.create_dataframe([1, 2, 3, 4]).to_df("a")
df1.show()
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df1 = session.create_dataframe([1, 2, 3, 4]).to_df("a")
#       2 df1.show()
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/snowpark/session.py:1541, in Session.create_dataframe(self, data, schema)
#    1538         project_columns.append(column(name))
#    1540 if self.sql_simplifier_enabled:
# -> 1541     df = DataFrame(
#    1542         self,
#    1543         SelectStatement(
#    1544             from_=SelectSnowflakePlan(
#    1545                 SnowflakeValues(attrs, converted), analyzer=self._analyzer
#    1546             ),
#    1547             analyzer=self._analyzer,
#    1548         ),
#    1549     ).select(project_columns)
#    1550 else:
#    1551     df = DataFrame(self, SnowflakeValues(attrs, converted)).select(
#    1552         project_columns
#    1553     )
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/snowpark/_internal/telemetry.py:183, in df_api_usage.<locals>.wrap(*args, **kwargs)
#     181 @functools.wraps(func)
#     182 def wrap(*args, **kwargs):
# --> 183     r = func(*args, **kwargs)
#     184     plan = r._select_statement or r._plan
#     185     # Some DataFrame APIs call other DataFrame APIs, so we need to remove the extra call
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/snowpark/dataframe.py:972, in DataFrame.select(self, *cols)
#     963     if join_plan:
#     964         return self._with_plan(
#     965             SelectStatement(
#     966                 from_=SelectSnowflakePlan(
#    (...)
#     970             ).select(names)
#     971         )
# --> 972     return self._with_plan(self._select_statement.select(names))
#     974 return self._with_plan(Project(names, join_plan or self._plan))
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/snowpark/_internal/analyzer/select_statement.py:480, in SelectStatement.select(self, cols)
#     478 final_projection = []
#     479 disable_next_level_flatten = False
# --> 480 new_column_states = derive_column_states_from_subquery(cols, self)
#     481 if new_column_states is None:
#     482     can_be_flattened = False
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/snowpark/_internal/analyzer/select_statement.py:882, in derive_column_states_from_subquery(cols, from_)
#     877 # if c is not an Attribute object, we will only care about the column name,
#     878 # so we can build a dummy Attribute with the column name
#     879 column_states.projection.append(
#     880     c if isinstance(c, Attribute) else Attribute(quoted_c_name)
#     881 )
# --> 882 from_c_state = from_.column_states.get(quoted_c_name)
#     883 if from_c_state and from_c_state.change_state != ColumnChangeState.DROPPED:
#     884     if c_name != analyzer.analyze(c):
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/snowpark/_internal/analyzer/select_statement.py:373, in SelectStatement.column_states(self)
#     371 if self._column_states is None:
#     372     if not self.projection and not self.has_clause:
# --> 373         self._column_states = self.from_.column_states
#     374     else:
#     375         super().column_states  # will assign value to self._column_states
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/snowpark/_internal/analyzer/select_statement.py:217, in Selectable.column_states(self)
#     212 """A dictionary that contains the column states of a query.
#     213 Refer to class ColumnStateDict.
#     214 """
#     215 if self._column_states is None:
#     216     self._column_states = initiate_column_states(
# --> 217         self.snowflake_plan.attributes, self.analyzer
#     218     )
#     219 return self._column_states
#
# File /opt/conda/lib/python3.8/functools.py:967, in cached_property.__get__(self, instance, owner)
#     965 val = cache.get(self.attrname, _NOT_FOUND)
#     966 if val is _NOT_FOUND:
# --> 967     val = self.func(instance)
#     968     try:
#     969         cache[self.attrname] = val
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:211, in SnowflakePlan.attributes(self)
#     209 @cached_property
#     210 def attributes(self) -> List[Attribute]:
# --> 211     output = analyze_attributes(self.schema_query, self.session)
#     212     self.schema_query = schema_value_statement(output)
#     213     return output
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/snowpark/_internal/analyzer/schema_utils.py:81, in analyze_attributes(sql, session)
#      78     session._run_query(sql)
#      79     return convert_result_meta_to_attribute(session._conn._cursor.description)
# ---> 81 return session._get_result_attributes(sql)
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/snowpark/session.py:1140, in Session._get_result_attributes(self, query)
#    1139 def _get_result_attributes(self, query: str) -> List[Attribute]:
# -> 1140     return self._conn.get_result_attributes(query)
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:87, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#      85 def wrap(*args, **kwargs):
#      86     try:
# ---> 87         return func(*args, **kwargs)
#      88     except snowflake.connector.errors.ProgrammingError as e:
#      89         tb = sys.exc_info()[2]
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/snowpark/_internal/server_connection.py:194, in ServerConnection.get_result_attributes(self, query)
#     192 @SnowflakePlan.Decorator.wrap_exception
#     193 def get_result_attributes(self, query: str) -> List[Attribute]:
# --> 194     return convert_result_meta_to_attribute(self._cursor.describe(query))
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/cursor.py:849, in SnowflakeCursor.describe(self, *args, **kwargs)
#     840 """Obtain the schema of the result without executing the query.
#     841
#     842 This function takes the same arguments as execute, please refer to that function
#    (...)
#     846     The schema of the result.
#     847 """
#     848 kwargs["_describe_only"] = kwargs["_is_internal"] = True
# --> 849 self.execute(*args, **kwargs)
#     850 return self._description
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/cursor.py:664, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, file_stream, num_statements)
#     662 logger.debug("executing SQL/command")
#     663 if self.is_closed():
# --> 664     Error.errorhandler_wrapper(
#     665         self.connection,
#     666         self,
#     667         InterfaceError,
#     668         {"msg": "Cursor is closed in execute.", "errno": ER_CURSOR_IS_CLOSED},
#     669     )
#     671 if _do_reset:
#     672     self.reset()
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/errors.py:275, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     252 @staticmethod
#     253 def errorhandler_wrapper(
#     254     connection: SnowflakeConnection | None,
#    (...)
#     257     error_value: dict[str, str | bool | int],
#     258 ) -> None:
#     259     """Error handler wrapper that calls the errorhandler method.
#     260
#     261     Args:
#    (...)
#     272         exception to the first handler in that order.
#     273     """
# --> 275     handed_over = Error.hand_to_other_handler(
#     276         connection,
#     277         cursor,
#     278         error_class,
#     279         error_value,
#     280     )
#     281     if not handed_over:
#     282         raise Error.errorhandler_make_exception(
#     283             error_class,
#     284             error_value,
#     285         )
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/errors.py:330, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     328 if cursor is not None:
#     329     cursor.messages.append((error_class, error_value))
# --> 330     cursor.errorhandler(connection, cursor, error_class, error_value)
#     331     return True
#     332 elif connection is not None:
#
# File /opt/conda/lib/python3.8/site-packages/snowflake/connector/errors.py:209, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     191 @staticmethod
#     192 def default_errorhandler(
#     193     connection: SnowflakeConnection,
#    (...)
#     196     error_value: dict[str, str],
#     197 ) -> None:
#     198     """Default error handler that raises an error.
#     199
#     200     Args:
#    (...)
#     207         A Snowflake error.
#     208     """
# --> 209     raise error_class(
#     210         msg=error_value.get("msg"),
#     211         errno=error_value.get("errno"),
#     212         sqlstate=error_value.get("sqlstate"),
#     213         sfqid=error_value.get("sfqid"),
#     214         done_format_msg=error_value.get("done_format_msg"),
#     215         connection=connection,
#     216         cursor=cursor,
#     217     )
#
# InterfaceError: 252006: Cursor is closed in execute.
