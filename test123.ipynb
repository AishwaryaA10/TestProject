# %%
# !pip show sanic
# Out:
# Name: sanic
# Version: 22.9.1
# Summary: A web server and web framework that's written to go fast. Build fast. Run fast.
# Home-page: http://github.com/sanic-org/sanic/
# Author: Sanic Community
# Author-email: admhpkns@gmail.com
# License: MIT
# Location: /testPVC/zdrivepackages1/Python/df3e3706-687f-45b3-aa0c-48add8a311db/3.7
# Requires: uvloop, websockets, httptools, multidict, aiofiles, ujson, sanic-routing
# Required-by:
