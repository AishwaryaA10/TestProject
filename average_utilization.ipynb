# %%
# !curl -H "Metadata-Flavor: Google" http://169.254.169.254/computeMetadata/v1/instance/service-accounts/default/token
# Out:
# {"access_token":"ya29.c.c0AY_VpZjjTBg4WQdZlmcuKuKUOwSjJk_3xFqVQ4c4L72FDzYP77PYoIHZTJQ64pKCiQZLgEtTYBPlvJ6r5TvdFNbM5_MNV_UNdOAlEi9WgJbNJjOPp2dKhhtN2NY9VUvioZ3oM_BnaQof4R88xnvAKyXxz7Cp_Hn7lrns-jtEUi2A_waI-m1ujpodZNk4ntaAhy9z99Z8QRnMY4A6I_xr3pClT8VkRiRZFZ9E7gmMMVfp4Rc_uyC20ZMUtvsKowYVkDOkGCXx7Fluwm5Bgkxt3ROvPNM3Kz8dB8UmJ-7d0eHLqKNAfV3iiqywd-2LwmSVNIEKggXzsO79zjsQE5U_XZ4FJ0XLOdw6aHXqH6xIQbaMufgeGc_e6cER7l32DhccIFgQqYdbmc6BagWP5LwuojAAIfXgBbYmEk_pWPlDhBxlIu7mH7QLavxfruBt8axfhDalmzmKflJaq6HlbTQ7JCszVi6m8atiRkjQ2r_4VgzRG9cGHgH1V4A6dfQeovPTKqzlRv9NcBOMNfcut7ibGzit7p4Vt0AKHwB4qbUxMsJ-M3G04_N4AP7PA-g45LjeYHlMTlyNrOWV8sCLbmLaZKSxrAtyEvcusqYliHR1E625CXfXs84FIeFwM0k8-9b91Fw8_jv1unJOZeo8itjnMfQUM9qya-Fex8manOQyt_qYSljz7F_un0buubnVplp6ksJwzlrmUXW7ZYa2x8zW_zWJBoItBIOZ16e5dkft84sfwYwW0zSerbUuBxo0_yJZRynUWXBj92I0QJxnlt-Voug-J0abORZtkrRrJyn4IcSr8mOvOWnQZoc48FmxFf1qFX0Xt7aSRmhMtISa83VBofcRh-lMre5-jVXpfYhXV4-BY2YSV_1vy5Xg6kdRncmZ_BSuzBnb_m1j3rYdXovI6wYX3ngmtMhFIaSVJthQV-WrQkF-yvdatksBmWZYlmFnMpegZbi1duhl
# ...

# %%
#this can be used in knights-watch code
# end_time is time.Now()
# aggregation.alignmentPeriod is the time for calculating average over req time_interval



import google.auth
import requests
from datetime import datetime, timedelta
from urllib.parse import quote


# Define the project ID
project_id = "fdc-development-408605"

# Define the current time and interval
# end_time = datetime.utcnow()
# start_time = end_time - timedelta(hours=6)

end_time = datetime.utcnow()
start_time = end_time - timedelta(minutes=60)

print("start_time", start_time)
print("end_time", end_time)

# Define filter string
filter_str = 'resource.type="k8s_container" AND resource.label."pod_name"="jy-0c513a10-8e38-4e7f-bc96-6171f06a9477-sunny10683796ltimindt" AND metric.type="kubernetes.io/container/cpu/limit_utilization"'
encoded_filter_str = quote(filter_str, safe='')

# Construct the API URL
sA = "ALIGN_MEAN"
sR = "REDUCE_MEAN"
# Construct the API URL
url = f'https://monitoring.googleapis.com/v3/projects/{project_id}/timeSeries?filter={encoded_filter_str}&aggregation.perSeriesAligner={sA}&aggregation.crossSeriesReducer={sR}&aggregation.alignmentPeriod=+60s&interval.startTime={start_time.strftime("%Y-%m-%dT%H:%M:%SZ")}&interval.endTime={end_time.strftime("%Y-%m-%dT%H:%M:%SZ")}'

print('url')
print(url)
# Get the access token
token = "ya29.c.c0AY_VpZjjTBg4WQdZlmcuKuKUOwSjJk_3xFqVQ4c4L72FDzYP77PYoIHZTJQ64pKCiQZLgEtTYBPlvJ6r5TvdFNbM5_MNV_UNdOAlEi9WgJbNJjOPp2dKhhtN2NY9VUvioZ3oM_BnaQof4R88xnvAKyXxz7Cp_Hn7lrns-jtEUi2A_waI-m1ujpodZNk4ntaAhy9z99Z8QRnMY4A6I_xr3pClT8VkRiRZFZ9E7gmMMVfp4Rc_uyC20ZMUtvsKowYVkDOkGCXx7Fluwm5Bgkxt3ROvPNM3Kz8dB8UmJ-7d0eHLqKNAfV3iiqywd-2LwmSVNIEKggXzsO79zjsQE5U_XZ4FJ0XLOdw6aHXqH6xIQbaMufgeGc_e6cER7l32DhccIFgQqYdbmc6BagWP5LwuojAAIfXgBbYmEk_pWPlDhBxlIu7mH7QLavxfruBt8axfhDalmzmKflJaq6HlbTQ7JCszVi6m8atiRkjQ2r_4VgzRG9cGHgH1V4A6dfQeovPTKqzlRv9NcBOMNfcut7ibGzit7p4Vt0AKHwB4qbUxMsJ-M3G04_N4AP7PA-g45LjeYHlMTlyNrOWV8sCLbmLaZKSxrAtyEvcusqYliHR1E625CXfXs84FIeFwM0k8-9b91Fw8_jv1unJOZeo8itjnMfQUM9qya-Fex8manOQyt_qYSljz7F_un0buubnVplp6ksJwzlrmUXW7ZYa2x8zW_zWJBoItBIOZ16e5dkft84sfwYwW0zSerbUuBxo0_yJZRynUWXBj92I0QJxnlt-Voug-J0abORZtkrRrJyn4IcSr8mOvOWnQZoc48FmxFf1qFX0Xt7aSRmhMtISa83VBofcRh-lMre5-jVXpfYhXV4-BY2YSV_1vy5Xg6kdRncmZ_BSuzBnb_m1j3rYdXovI6wYX3ngmtMhFIaSVJthQV-WrQkF-yvdatksBmWZYlmFnMpegZbi1duhlh8yW8beSi72RX6tl9_pk3qQV4XaOs5lQg2X6ndRR9_n"



# Make the API call

response = requests.get(
    url,
    headers={"Authorization": f"Bearer {token}"}
)

# Print the response
print(response.json())

# %%
print('1')
