# %%
from google.cloud import monitoring_v3
import time

project_id = "fdc-development-408605"
pod_name = "jy-e557679f-02f1-4af5-9f8a-e61a2a0754a1-sunny10683796ltimindt"
client = monitoring_v3.MetricServiceClient()
project_name = f"projects/{project_id}"

now = time.time()
seconds = int(now)
nanos = int((now - seconds) * 10 ** 9)
interval = monitoring_v3.TimeInterval(
    {
        "end_time": {"seconds": seconds, "nanos": nanos},
        "start_time": {"seconds": (seconds - 3600), "nanos": nanos},
    }
)
aggregation = monitoring_v3.Aggregation(
    {
        "alignment_period": {"seconds": 1200},  # 20 minutes
        "per_series_aligner": monitoring_v3.Aggregation.Aligner.ALIGN_MEAN,
        "cross_series_reducer": monitoring_v3.Aggregation.Reducer.REDUCE_MEAN,
    }
)

filter_str = f'resource.type="k8s_pod" AND resource.labels.project_id="{project_id}" AND resource.labels.location="us-central1-a" AND resource.labels.cluster_name="fdc-development" AND resource.labels.namespace_name="NAMESPACE_NAME" AND resource.labels.pod_name="{pod_name}" AND metric.type="kubernetes.io/container/cpu/limit_utilization"'

results = client.list_time_series(
    request={
        "name": project_name,
        "filter": filter_str,
        "interval": interval,
        "view": monitoring_v3.ListTimeSeriesRequest.TimeSeriesView.FULL,
        "aggregation": aggregation,
    }
)
for result in results:
    print(result)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgument                           Traceback (most recent call last)
# Cell In[6], line 28
#      18 aggregation = monitoring_v3.Aggregation(
#      19     {
#      20         "alignment_period": {"seconds": 1200},  # 20 minutes
#    (...)
#      23     }
#      24 )
#      26 filter_str = f'resource.type="k8s_pod" AND resource.labels.project_id="{project_id}" AND resource.labels.location="us-central1-a" AND resource.labels.cluster_name="fdc-development" AND resource.labels.namespace_name="NAMESPACE_NAME" AND resource.labels.pod_name="{pod_name}" AND metric.type="kubernetes.io/container/cpu/limit_utilization"'
# ---> 28 results = client.list_time_series(
#      29     request={
#      30         "name": project_name,
#      31         "filter": filter_str,
#      32         "interval": interval,
#      33         "view": monitoring_v3.ListTimeSeriesRequest.TimeSeriesView.FULL,
# ...
