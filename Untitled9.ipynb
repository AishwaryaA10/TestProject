# %%
from google.cloud import monitoring_v3
import time
project_id = "fdc-development-408605"
pod_name = "jy-e557679f-02f1-4af5-9f8a-e61a2a0754a1-sunny10683796ltimindt"
client = monitoring_v3.MetricServiceClient()
project_name = f"projects/{project_id}"

now = time.time()
seconds = int(now)
nanos = int((now - seconds) * 10 ** 9)
interval = monitoring_v3.TimeInterval(
    {
        "end_time": {"seconds": seconds, "nanos": nanos},
        "start_time": {"seconds": (seconds - 3600), "nanos": nanos},
    }
)
aggregation = monitoring_v3.Aggregation(
    {
        "alignment_period": {"seconds": 1200},  # 20 minutes
        "per_series_aligner": monitoring_v3.Aggregation.Aligner.ALIGN_MEAN,
        "cross_series_reducer": monitoring_v3.Aggregation.Reducer.REDUCE_MEAN,
    }
)

filter_str = f'resource.type="k8s_container" AND resource.label."pod_name"="jy-e557679f-02f1-4af5-9f8a-e61a2a0754a1-sunny10683796ltimindt" AND metric.type="kubernetes.io/container/cpu/limit_utilization"'

# kubernetes.io/container/cpu/limit_utilization

results = client.list_time_series(
    request={
        "name": project_name,
        "filter": filter_str,
        "interval": interval,
        "view": monitoring_v3.ListTimeSeriesRequest.TimeSeriesView.FULL,
        "aggregation": aggregation,
    }
)
for result in results:
    print(result)
# Out:
# metric {
#   type: "kubernetes.io/container/cpu/limit_utilization"
# }
# resource {
#   type: "k8s_container"
#   labels {
#     key: "project_id"
#     value: "fdc-development-408605"
#   }
# }
# metric_kind: GAUGE
# value_type: DOUBLE
# points {
#   interval {
#     end_time {
#       seconds: 1710852981
#       nanos: 871914000
#     }
#     start_time {
#       seconds: 1710852981
#       nanos: 871914000
#     }
#   }
#   value {
#     double_value: 0.0029710965571609063
#   }
# }
# points {
#   interval {
#     end_time {
#       seconds: 1710851781
#       nanos: 871914000
#     }
#     start_time {
#       seconds: 1710851781
#       nanos: 871914000
#     }
#   }
#   value {
#     double_value: 0.004566065105676604
#   }
# }
# points {
#   interval {
#     end_time {
#       seconds: 1710850581
#       nanos: 871914000
#     }
#     start_time {
#       seconds: 1710850581
#       nanos: 871914000
#     }
#   }
#   value {
#     double_value: 0.0040989566668332188
#   }
# }

# %%
o/!curl -H "Metadata-Flavor: Google" http://169.254.169.254/computeMetadata/v1/instance/service-accounts/default/token
# Out:
# {"access_token":"ya29.c.c0AY_VpZg7Y5kbXL2px5iFnHepfs2VDaEfhdVGQ9F0P-go1taVbv50N9C01NhMw9ssvZ8WSSJU_iba_sUUQXdKFRC8BhDahs3mLajRgKuSLxpTCqQ4SThGx3r-gx95p1Ia1FOLiUO5i5Ru6ELVy19B1odDEX1CoTd2ghCdAKwJWvCFmC2r2n1gyAOF8WmV-WuxAUhtPCvuoe-a9QSJ0lAKgTHzfphpL5Y5Zupe4tKuX7gMBc5TnxxpqmjNKznRp140HP23vuJM5ajYliBAfE_hgq3UptdtGI3nAFHDgaYHNz9evLgZqR60kqT0ovOgOVJqwySBwDeJTnFWDEEAtcLSb4JPPXBWYaAU1MimzZtni7nMseHwXoY24RdsXVI6FevTMnMWd-UdEPPIBlDzuNIXaoNNiqayScvQ8ws0l3MEun2QwSztbKm9MP9ROmVd8UILZoTjefwkBc_0qMxc2vQgryBEwKCqupCAknqK5REVqKHgoaWY78_9VCmFW_zhlEOddCjCnxyeg0eaCFgaTWRh8HKxmZUVv0CBDHA68_SjXEFGLHr5vE3_YierC9doSFMFGy-19u7luo9HHy3TqE67mSqNBbRmOu_dfVZq0kT_kwL627P2M5tyJWIddqW0i7_ndIxJIZcOh_fZY9BgwOfYUSzqeSnb52k_Id0X99lFYX6nhaZV7b-sVW-s7OJrYWVfs1V2WkOqzpVXBdoud0i2JJfpBJO_R-2fpvbjqta0Vn3XsmZRd11ro16zp3nwJldlcktm4l8kfVwQkiMMfB7sat8rolXufcxlzn0ato711I2aJtOy5psF4UyJQ_rZFOOS5xoMu-ykfc3WQuRQBksMt30Jh0aXBewuwBXnUuRcmouI9XS3zYlf0QhycZyOj5cJbsqOBYtMyMQJUSQ5btFg2hZc2O3W20J5tSbf34Y4-3Xm8n5-Q70ZQzZXxvnt4ysUzS7w3abuulWsi9hOQFQa1IdfuoSmgYy9YZfp_gy3VimB32UkX7a3vjw","expires_in":3583,"token_type":"Bearer"}

# %%
import google.auth
import requests
from datetime import datetime, timedelta
from urllib.parse import quote

# Get credentials
credentials, _ = google.auth.default(scopes=["https://www.googleapis.com/auth/cloud-platform"])
print('ss')
print(credentials)
print('ss')

# Define the project ID
project_id = "fdc-development-408605"

# Define the current time and interval
end_time = datetime.utcnow()
start_time = end_time - timedelta(hours=1)

# Define filter string
filter_str = 'resource.type="k8s_container" AND resource.label."pod_name"="jy-e557679f-02f1-4af5-9f8a-e61a2a0754a1-sunny10683796ltimindt" AND metric.type="kubernetes.io/container/cpu/limit_utilization"'
encoded_filter_str = quote(filter_str, safe='')

# Construct the API URL
url = f'https://monitoring.googleapis.com/v3/projects/{project_id}/timeSeries?filter={encoded_filter_str}&interval.startTime={start_time.strftime("%Y-%m-%dT%H:%M:%SZ")}&interval.endTime={end_time.strftime("%Y-%m-%dT%H:%M:%SZ")}'

# Get the access token
token = credentials.token
print('tojken pr')
print(token)
print('asas')
# Make the API call

cred2= google.oauth2.credentials.Credentials(
    'access_token')
print('aaaadsa')
print(cred2.access_token)

response = requests.get(
    url,
    headers={"Authorization": f"Bearer {token}"}
)

# Print the response
print(response.json())
# Out:
# ss
# <google.auth.compute_engine.credentials.Credentials object at 0x7c406c2e8340>
# ss
# tojken pr
# None
# asas
# aaaadsa
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 36
#      33 cred2= google.oauth2.credentials.Credentials(
#      34     'access_token')
#      35 print('aaaadsa')
# ---> 36 print(cred2.access_token)
#      38 response = requests.get(
#      39     url,
#      40     headers={"Authorization": f"Bearer {token}"}
#      41 )
#      43 # Print the response
#
# AttributeError: 'Credentials' object has no attribute 'access_token'
