# %%
from flask import g


delete_images = {
    "Spark-3.6": "", 
    "Spark-3.8": "",
    "Spark Distributed": "", 
    "R-Jupyter": "", 
    "Python-3.6": "", 
    "Python-3.7": "", 
    "RStudio-4": "5caa1af9-ab99-4bd4-80b1-da41f8b3d2ac",
    "RStudio_RHEL-4.1": "", 
    "Jupyterlab-3.6": "", 
    "Jupyterlab-3.7": "", 
    "R-Jupyterlab": "",
    "spark-Jupyterlab": "", 
    "VSCode-Scala2.12": "", 
    "Jupyterlab-3.10-SPCS": ""}

request_headers = {
            "X-Auth-Userid": "swapnil.warule@fosfor.com",
            "X-Project-Id": "ee97bf13-dbe9-46d9-9281-a2b1a3762897",
            "X-Auth-Username": "swapnil.warule@fosfor.com",
            "X-Auth-Email": "swapnil.warule@fosfor.com"
        }

delete_images1 = ["Spark-3.6", "Spark-3.8"]

url= "http://notebooks-api:5000/notebooks/api/v1/docker-images"
resp = requests.get(url, headers=request_headers)
if resp.status_code == 200:
    output = resp.json()[0]
print()


#for image in delete_images:
#url = "http://notebooks-api:5000/notebooks/api/v1/docker-images/{}".format("5caa1af9-ab99-4bd4-80b1-da41f8b3d2ac")
#url = "http://notebooks-api:5000/notebooks/api/v1/docker-images/{}".format(delete_images[image])
#resp = requests.delete(url = url, headers = request_headers)
    
#print(resp)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 33
#      31 if resp.status_code == 200:
#      32     output = resp.json()[0]
# ---> 33 print(output.split())
#      36 #for image in delete_images:
#      37 #url = "http://notebooks-api:5000/notebooks/api/v1/docker-images/{}".format("5caa1af9-ab99-4bd4-80b1-da41f8b3d2ac")
#      38 #url = "http://notebooks-api:5000/notebooks/api/v1/docker-images/{}".format(delete_images[image])
#      39 #resp = requests.delete(url = url, headers = request_headers)
#      40
#      41 #print(resp)
#
# AttributeError: 'dict' object has no attribute 'split'
