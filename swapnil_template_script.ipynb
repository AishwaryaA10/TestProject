# %%
from flask import g


delete_images = {
    "Spark-3.6": "", 
    "Spark-3.8": "",
    "Spark Distributed": "", 
    "R-Jupyter": "", 
    "Python-3.6": "", 
    "Python-3.7": "", 
    "RStudio-4": "5caa1af9-ab99-4bd4-80b1-da41f8b3d2ac",
    "RStudio_RHEL-4.1": "", 
    "Jupyterlab-3.6": "", 
    "Jupyterlab-3.7": "", 
    "R-Jupyterlab": "",
    "spark-Jupyterlab": "", 
    "VSCode-Scala2.12": "", 
    "Jupyterlab-3.10-SPCS": ""}

request_headers = {
            "X-Auth-Userid": "swapnil.warule@fosfor.com",
            "X-Project-Id": "ee97bf13-dbe9-46d9-9281-a2b1a3762897",
            "X-Auth-Username": "swapnil.warule@fosfor.com",
            "X-Auth-Email": "swapnil.warule@fosfor.com"
        }

delete_images1 = ["Spark-3.6", "Spark-3.8"]

url= "http://notebooks-api:5000/notebooks/api/v1/docker-images"
resp = requests.get(url, headers=request_headers)
if resp.status_code == 200:
    print(resp.json()[0])
#print(resp.data)


#for image in delete_images:
#url = "http://notebooks-api:5000/notebooks/api/v1/docker-images/{}".format("5caa1af9-ab99-4bd4-80b1-da41f8b3d2ac")
#url = "http://notebooks-api:5000/notebooks/api/v1/docker-images/{}".format(delete_images[image])
#resp = requests.delete(url = url, headers = request_headers)
    
#print(resp)
# Out:
# {'auto_commit': True, 'base_image_id': None, 'base_template': 'JupyterLab', 'conda_packages': None, 'cran_packages': None, 'created_by': 'system', 'created_on': 'Fri, 23 Feb 2024 05:55:29 GMT', 'description': 'Prebuilt image', 'docker_file': None, 'docker_url': 'us-central1-docker.pkg.dev/fdc-development-408605/dev-refract-ms/mosaic-ai-logistics/mosaic-notebooks-manager/jupyter/3.10:3.10V1.0.8', 'executor_resource_id': '001d18b3-877a-4340-b313-135244973eb3', 'git_macros_config': None, 'gpu_docker_url': 'us-central1-docker.pkg.dev/fdc-development-408605/dev-refract-ms/mosaic-ai-logistics/mosaic-notebooks-manager/jupyter/3.10:3.10V1.0.8', 'icon': 'python-jupyterlab.svg', 'id': 'f6c2da6d-a560-4428-943a-2d6abb5a1c39', 'index_url': None, 'init_script': None, 'kernel_type': 'python', 'name': 'Jupyterlab-3.10', 'number_of_executors': None, 'package_type': 'pip', 'pip_packages': None, 'resource_id': 'da3f755d-7dab-4df4-9f48-5cce0f263454', 'spcs_data': {}, 'tags': ['type=jupyterlab', 'default=true', 'os=manylinux1_x86_64', 'pyversion=310', 'version=3.10'], 'type': 'PRE_BUILD', 'updated_by': 'system', 'updated_on': 'Fri, 23 Feb 2024 13:30:01 GMT'}
