# %%
delete_images = {
    "Spark-3.6", 
    "Spark-3.8",
    "Spark Distributed", 
    "R-Jupyter", 
    "Python-3.6", 
    "Python-3.7", 
    "RStudio-4": "5caa1af9-ab99-4bd4-80b1-da41f8b3d2ac",
    "RStudio_RHEL-4.1", 
    "Jupyterlab-3.6", 
    "Jupyterlab-3.7", 
    "R-Jupyterlab",
    "spark-Jupyterlab", 
    "VSCode-Scala2.12", 
    "Jupyterlab-3.10-SPCS"}

request_headers = {
            Headers.x_auth_username: g.user["first_name"],
            Headers.x_auth_email: g.user["email_address"],
            Headers.x_auth_userid: g.user["mosaicId"],
        }


for image in delete_images:
    url = ""
    url = "/v1/docker-images/{}".format(delete_images[image])
    requests.delete
