# %%
from flask import g


delete_images = {
    "Spark-3.6": "", 
    "Spark-3.8": "",
    "Spark Distributed": "", 
    "R-Jupyter": "", 
    "Python-3.6": "", 
    "Python-3.7": "", 
    "RStudio-4": "5caa1af9-ab99-4bd4-80b1-da41f8b3d2ac",
    "RStudio_RHEL-4.1": "", 
    "Jupyterlab-3.6": "", 
    "Jupyterlab-3.7": "", 
    "R-Jupyterlab": "",
    "spark-Jupyterlab": "", 
    "VSCode-Scala2.12": "", 
    "Jupyterlab-3.10-SPCS": ""}

request_headers = {
            "X-Auth-Userid": "swapnil.warule@fosfor.com",
            "X-Project-Id": "ee97bf13-dbe9-46d9-9281-a2b1a3762897",
            "X-Auth-Username": "swapnil.warule@fosfor.com",
            "X-Auth-Email": "swapnil.warule@fosfor.com"
        }

delete_images1 = ["Spark-3.6", "Spark-3.8"]

url= "http://notebooks-api:5000/notebooks/api/v1/docker-images"
resp = requests.get(url, headers=request_headers)
print(resp.data)


#for image in delete_images:
#url = "http://notebooks-api:5000/notebooks/api/v1/docker-images/{}".format("5caa1af9-ab99-4bd4-80b1-da41f8b3d2ac")
#url = "http://notebooks-api:5000/notebooks/api/v1/docker-images/{}".format(delete_images[image])
#resp = requests.delete(url = url, headers = request_headers)
    
#print(resp)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 31
#      29 url= "http://notebooks-api:5000/notebooks/api/v1/docker-images"
#      30 resp = requests.get(url, headers=request_headers)
# ---> 31 print(resp.data)
#      34 #for image in delete_images:
#      35 #url = "http://notebooks-api:5000/notebooks/api/v1/docker-images/{}".format("5caa1af9-ab99-4bd4-80b1-da41f8b3d2ac")
#      36 #url = "http://notebooks-api:5000/notebooks/api/v1/docker-images/{}".format(delete_images[image])
#      37 #resp = requests.delete(url = url, headers = request_headers)
#      38
#      39 #print(resp)
#
# AttributeError: 'Response' object has no attribute 'data'
