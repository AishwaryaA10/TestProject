# %%
from flask import g

request_headers = {
            "X-Auth-Userid": "swapnil.warule@fosfor.com",
            "X-Project-Id": "ee97bf13-dbe9-46d9-9281-a2b1a3762897",
            "X-Auth-Username": "swapnil.warule@fosfor.com",
            "X-Auth-Email": "swapnil.warule@fosfor.com"
        }


template_names = ["Spark-3.6", "Spark-3.8", "Spark Distributed", "R-Jupyter", "Python-3.6", "Python-3.7", "RStudio-4",
                 "RStudio_RHEL-4.1", "Jupyterlab-3.6", "Jupyterlab-3.7", "R-Jupyterlab", "spark-Jupyterlab",
                 "VSCode-Scala2.12", "Jupyterlab-3.10-SPCS"]

url= "http://notebooks-api:5000/notebooks/api/v1/docker-images"
resp = requests.get(url, headers=request_headers)
if resp.status_code == 200:
    output = resp.json()

delete_images = []
for item in output:
    if item["name"] in template_names:
        delete_images.append(item["id"])
        print(item["name"], item["id"])
print("\nImages to be deleted-", delete_images)
        
        
for image in delete_images:
    try:
        url = "http://notebooks-api:5000/notebooks/api/v1/docker-images/{}".format(image)
        resp = requests.delete(url, headers = request_headers)
        print("\n Template image deleted")
    except Exception as e:
        print("Exception")
    
print("Completed")
# Out:
# Python-3.6 7a54cd49-10e0-49ba-954b-f597455d6843
# Python-3.7 32cbe7d3-24a1-44ec-b3a9-15ab790c0860
# Jupyterlab-3.6 3985f816-fe50-4405-9c18-d667cc8e3a35
# Jupyterlab-3.7 96e6e205-5204-4e44-ace0-89ab4a890e6f
# R-Jupyterlab b8e88b14-93b8-416b-97f5-511d63d31331
# Jupyterlab-3.10-SPCS f056d43b-07a1-4117-991a-ba6c85b70574
# R-Jupyter 411fff31-6ffd-4e8c-bc3f-ea0dd503273d
# Spark-3.6 ceb842ae-e6c2-44fb-9a7b-9b0b6599dca1
# spark-Jupyterlab e321b9e0-e28c-4313-a851-8fed449f5494
# VSCode-Scala2.12 05e2b21e-5f7d-47a5-b65e-f75182e34e84
# Spark Distributed 41eb9c3d-081a-4080-8acb-ff8ba9f24b45
# RStudio_RHEL-4.1 d664bc93-fcfa-4b7c-b713-47502b962e80
# Spark-3.8 d41d238b-f9a3-4629-98cc-175aa520298d
# RStudio-4 264c32e2-c1db-49d9-a8c2-2f1b2181b270
#
# Images to be deleted- ['7a54cd49-10e0-49ba-954b-f597455d6843', '32cbe7d3-24a1-44ec-b3a9-15ab790c0860', '3985f816-fe50-4405-9c18-d667cc8e3a35', '96e6e205-5204-4e44-ace0-89ab4a890e6f', 'b8e88b14-93b8-416b-97f5-511d63d31331', 'f056d43b-07a1-4117-991a-ba6c85b70574', '411fff31-6ffd-4e8c-bc3f-ea0dd503273d', 'ceb842ae-e6c2-44fb-9a7b-9b0b6599dca1', 'e321b9e0-e28c-4313-a851-8fed449f5494', '05e2b21e-5f7d-47a5-b65e-f75182e34e84', '41eb9c3d-081a-4080-8acb-ff8ba9f24b45', 'd664bc93-fcfa-4b7c-b713-47502b962e80', 'd41d238b-f9a3-4629-98cc-175aa520298d', '264c32e2-c1db-49d9-a8c2-2f1b2181b270']
# <Response [500]>
