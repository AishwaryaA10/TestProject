# %%
from flask import g

delete_images = {
    "Spark-3.6": "", 
    "Spark-3.8": "",
    "Spark Distributed": "", 
    "R-Jupyter": "", 
    "Python-3.6": "", 
    "Python-3.7": "", 
    "RStudio-4": "5caa1af9-ab99-4bd4-80b1-da41f8b3d2ac",
    "RStudio_RHEL-4.1": "", 
    "Jupyterlab-3.6": "", 
    "Jupyterlab-3.7": "", 
    "R-Jupyterlab": "",
    "spark-Jupyterlab": "", 
    "VSCode-Scala2.12": "", 
    "Jupyterlab-3.10-SPCS": ""}

request_headers = {
            "X-Auth-Userid": "swapnil.warule@fosfor.com",
            "X-Project-Id": "ee97bf13-dbe9-46d9-9281-a2b1a3762897",
            "X-Auth-Username": "swapnil.warule@fosfor.com",
            "X-Auth-Email": "swapnil.warule@fosfor.com"
            #"Authorization": "Token eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJsSDNBcUxCUFUxLS14QXkxbnU0amJoU2hyNWIwTWlwd3RqYWVkdlpOSXZRIn0.....nRDEz7EURDHgtWak1sWJk62ElIvtQGu06iUGwwXDcXL1HVbriN9CJCi5B8wn3pp5TJcrFeSinA-hOSrK__mreweTdLdDN4aIDtSGPkWpqnwsxH_NoEP3GVPib3OdRoKl0f19AuMYQ2ncYwdWcExxJyxk0nbiq9KSjnEAzIMKJvUZqkSrkMA4rKt6Y8JjGCdD4iBGZJgnC9ajQAT878IFcjEAXVONt_shvzsltcTJiqyoTNjaNmrJuV8CnrhQtVwsj0ohJwKNyMjFSwqK7k0I9_7UboUe4JXjzPDsvuXKjcS_WOL3s3emlDWldrKkmg0ptZwLH6lvdHnocmDm-tnEMg"
        }


#for image in delete_images:
url = "http://notebooks-api:5000/notebooks/api/v1/docker-images/{}".format("5caa1af9-ab99-4bd4-80b1-da41f8b3d2ac")
#url = "http://notebooks-api:5000/notebooks/api/v1/docker-images/{}".format(delete_images[image])
resp = requests.delete(url = url, headers = request_headers)
    
print(resp)
# Out:
# <Response [204]>
