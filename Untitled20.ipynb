# %%
f = open("/tmp/pip_packages/pythontree.txt", r)
# Out:
# Name: jupyterlab
# Version: 3.2.4
# Summary: JupyterLab computational environment
# Home-page: https://jupyter.org
# Author: Jupyter Development Team
# Author-email: jupyter@googlegroups.com
# License: UNKNOWN
# Location: /opt/conda/lib/python3.8/site-packages
# Requires: jupyter-core, nbclassic, ipython, jinja2, jupyterlab-server, tornado, jupyter-server, packaging
# Required-by:
