# %%
raise Exception("Explicitly generated exception")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-1-e9b196e7e2a3> in <module>
# ----> 1 raise Exception("Explicitly generated exception")
#
# Exception: Explicitly generated exception
