# %%
delete_images = {
    "Spark-3.6": "", 
    "Spark-3.8",
    "Spark Distributed", 
    "R-Jupyter", 
    "Python-3.6", 
    "Python-3.7", 
    "RStudio-4",
    "RStudio_RHEL-4.1", 
    "Jupyterlab-3.6", 
    "Jupyterlab-3.7", 
    "R-Jupyterlab",
    "spark-Jupyterlab", 
    "VSCode-Scala2.12", 
    "Jupyterlab-3.10-SPCS"}
