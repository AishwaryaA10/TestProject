# %%
library(mosaicrml)

# %%
ping()
# Out:
# [1] "pong1"

# %%
files <- list_files()
# Out:
# [1] "sdfg"

# %%
files$data_files
# Out:
# [[1]]
# [[1]][[1]]
# [[1]][[1]]$last_modified
# [1] "Jun 25, 2020 14:23"
#
# [[1]][[1]]$name
# [1] "100 Sales Records.csv"
#
# [[1]][[1]]$size
# [1] "12.45 KB"
#
#
#
# [[2]]
# [[2]][[1]]
# [[2]][[1]]$last_modified
# [1] "Jun 16, 2020 19:46"
#
# [[2]][[1]]$name
# [1] "10653151-112019.pdf"
#
# [[2]][[1]]$size
# [1] "74.45 KB"
#
#
#
# [[3]]
# [[3]][[1]]
# [[3]][[1]]$last_modified
# [1] "Jun 16, 2020 18:57"
#
# [[3]][[1]]$name
# [1] "1112.tar.gz"
#
# [[3]][[1]]$size
# [1] "346.13 KB"
#
#
#
# [[4]]
# [[4]][[1]]
# [[4]][[1]]$last_modified
# [1] "Jun 18, 2020 17:49"
#
# [[4]][[1]]$name
# [1] "17-Jul-19/APIs/APIObjects.sh"
#
# [[4]][[1]]$size
# [1] "1.48 KB"
#
#
#
# [[5]]
# [[5]][[1]]
# [[5]][[1]]$last_modified
# [1] "Jun 18, 2020 17:49"
#
# [[5]][[1]]$name
# [1] "17-Jul-19/APIs/ApiRequest.sh"
#
# [[5]][[1]]$size
# [1] "2.73 KB"
#
#
#
# [[6]]
# [[6]][[1]]
# [[6]][[1]]$last_modified
# [1] "Jun 23, 2020 14:40"
#
# [[6]][[1]]$name
# [1] "17-Jul-19/APIs/Hari/mosaicl.jpg"
#
# [[6]][[1]]$size
# ...

# %%
download("3/gbiml_model.yaml", "/tmp/", folder_struct = TRUE)

# %%
delete("3/gbiml_model.yaml")

# %%
upload("/tmp/gbiml_model.yaml", "3/")
