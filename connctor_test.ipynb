# %%
# !pip install --no-cache-dir fdc-connector-python-sdk==1.0.6 --extra-index-url https://__token__:glpat-ZjxNEisHtmaFhxnYefd8@gitlab.fosfor.com/api/v4/projects/283/packages/pypi/simple

# %%
from fdc_connector_python_sdk.factory.connectorFactory import ConnectionFactory
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from fdc_connector_python_sdk.factory.connectorFactory import ConnectionFactory
#
# File /tmp/pip_packages/fdc_connector_python_sdk/factory/connectorFactory.py:2
#       1 from fdc_connector_python_sdk.interfaceDTO.snowflakeDTO import SnowflakeDTO
# ----> 2 from fdc_connector_python_sdk.connectors.snowflake import \
#       3     SnowflakeConnector
#       6 class ConnectionFactory:
#       7     """
#       8     Connection Factory class is the entrypoint to get the connector class and dto class based on db_type.
#       9     """
#
# File /tmp/pip_packages/fdc_connector_python_sdk/connectors/snowflake.py:2
#       1 import re
# ----> 2 import snowflake.connector.errors
#       3 import snowflake.connector
#       4 import logging
#
# File /tmp/pip_packages/snowflake/connector/__init__.py:19
#      16 import logging
#      17 from logging import NullHandler
# ---> 19 from .connection import SnowflakeConnection
#      20 from .cursor import DictCursor
#      21 from .dbapi import (
#      22     BINARY,
#      23     DATETIME,
#    (...)
#      33     TimestampFromTicks,
#      34 )
#
# File /tmp/pip_packages/snowflake/connector/connection.py:33
#      30 from cryptography.hazmat.primitives import serialization
#      31 from cryptography.hazmat.primitives.asymmetric.rsa import RSAPrivateKey
# ---> 33 from . import errors, proxy
#      34 from ._query_context_cache import QueryContextCache
#      35 from .auth import (
#      36     FIRST_PARTY_AUTHENTICATORS,
#      37     Auth,
#    (...)
#      44     AuthByWebBrowser,
#      45 )
#
# File /tmp/pip_packages/snowflake/connector/errors.py:15
#      12 from logging import getLogger
#      13 from typing import TYPE_CHECKING, Any
# ---> 15 from .compat import BASE_EXCEPTION_CLASS
#      16 from .secret_detector import SecretDetector
#      17 from .telemetry import TelemetryData, TelemetryField
#
# File /tmp/pip_packages/snowflake/connector/compat.py:19
#      16 import urllib.request
#      17 from typing import Any
# ---> 19 from . import constants
#      21 IS_LINUX = platform.system() == "Linux"
#      22 IS_WINDOWS = platform.system() == "Windows"
#
# File /tmp/pip_packages/snowflake/connector/constants.py:12
#       9 from enum import Enum, auto, unique
#      10 from typing import TYPE_CHECKING, Any, Callable, DefaultDict, NamedTuple
# ---> 12 from .options import pyarrow as pa
#      13 from .sf_dirs import _resolve_platform_dirs
#      15 if TYPE_CHECKING:
#
# File /tmp/pip_packages/snowflake/connector/options.py:130
#     126         return MissingKeyring(), False
#     129 # Create actual constants to be imported from this file
# --> 130 pandas, pyarrow, installed_pandas = _import_or_missing_pandas_option()
#     131 keyring, installed_keyring = _import_or_missing_keyring_option()
#
# File /tmp/pip_packages/snowflake/connector/options.py:76, in _import_or_missing_pandas_option()
#      70 """This function tries importing the following packages: pandas, pyarrow.
#      71
#      72 If available it returns pandas and pyarrow packages with a flag of whether they were imported.
#      73 It also warns users if they have an unsupported pyarrow version installed if possible.
#      74 """
#      75 try:
# ---> 76     pandas = importlib.import_module("pandas")
#      77     # since we enable relative imports without dots this import gives us an issues when ran from test directory
#      78     from pandas import DataFrame  # NOQA
#
# File /opt/conda/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File /tmp/pip_packages/pandas/__init__.py:22
#      19 del hard_dependencies, dependency, missing_dependencies
#      21 # numpy compat
# ---> 22 from pandas.compat import is_numpy_dev as _is_numpy_dev
#      24 try:
#      25     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#
# File /tmp/pip_packages/pandas/compat/__init__.py:15
#      12 import sys
#      14 from pandas._typing import F
# ---> 15 from pandas.compat.numpy import (
#      16     is_numpy_dev,
#      17     np_version_under1p19,
#      18     np_version_under1p20,
#      19 )
#      20 from pandas.compat.pyarrow import (
#      21     pa_version_under1p01,
#      22     pa_version_under2p0,
#      23     pa_version_under3p0,
#      24     pa_version_under4p0,
#      25 )
#      27 PY39 = sys.version_info >= (3, 9)
#
# File /tmp/pip_packages/pandas/compat/numpy/__init__.py:4
#       1 """ support numpy compatibility across versions """
#       2 import numpy as np
# ----> 4 from pandas.util.version import Version
#       6 # numpy versioning
#       7 _np_version = np.__version__
#
# File /tmp/pip_packages/pandas/util/__init__.py:1
# ----> 1 from pandas.util._decorators import (  # noqa:F401
#       2     Appender,
#       3     Substitution,
#       4     cache_readonly,
#       5 )
#       7 from pandas.core.util.hashing import (  # noqa:F401
#       8     hash_array,
#       9     hash_pandas_object,
#      10 )
#      13 def __getattr__(name):
#
# File /tmp/pip_packages/pandas/util/_decorators.py:14
#       6 from typing import (
#       7     Any,
#       8     Callable,
#       9     Mapping,
#      10     cast,
#      11 )
#      12 import warnings
# ---> 14 from pandas._libs.properties import cache_readonly  # noqa:F401
#      15 from pandas._typing import F
#      18 def deprecate(
#      19     name: str,
#      20     alternative: Callable[..., Any],
#    (...)
#      25     msg: str | None = None,
#      26 ) -> Callable[[F], F]:
#
# File /tmp/pip_packages/pandas/_libs/__init__.py:13
#       1 __all__ = [
#       2     "NaT",
#       3     "NaTType",
#    (...)
#       9     "Interval",
#      10 ]
# ---> 13 from pandas._libs.interval import Interval
#      14 from pandas._libs.tslibs import (
#      15     NaT,
#      16     NaTType,
#    (...)
#      21     iNaT,
#      22 )
#
# File /tmp/pip_packages/pandas/_libs/interval.pyx:1, in init pandas._libs.interval()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
snowflake_connector = ConnectionFactory.get_connector("snowflake")
snowflake_dto = ConnectionFactory.get_dto("SNOWFLAKE")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 snowflake_connector = ConnectionFactory.get_connector("snowflake")
#       2 snowflake_dto = ConnectionFactory.get_dto("SNOWFLAKE")
#
# NameError: name 'ConnectionFactory' is not defined

# %%
param_dict = snowflake_dto.set_param(auth_type=auth_type, **connection_params)
session = snowflake_connector.get_snowpark_session(param_dict)
print(session)
