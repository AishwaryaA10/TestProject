#  16856182.518138584,
#  905938.3801071716,
#  2925992.0959411897,
#  14093694.83417606,
#  2919012.4440153143,
#  5922371.318843241,
#  12350403.666482365,
#  2174823.138204798,
#  2251488.445225787,
#  3945774.127017532,
#  1952575.2489634105,
#  3016257.422551741,
#  2916109.091177709,
#  2534307.731573497,
#  2419014.1430212446,
#  5675220.6590992,
#  3223934.957349492,
#  1241105.8003806572,
#  3392948.964274308,
#  3341035.2326127235,
#  11234928.179975294,
#  6512834.2905571,
#  2863546.143883272,
#  16007503.424911888,
#  2892974.5916343164,
#  8792105.76433825,
#  10708257.616719225,
#  2748581.702385441,
#  6115400.421560037,
#  2542735.0068426593,
#  4706566.706159095,
#  3269040.1830676952,
#  7294598.118468806,
#  2508882.209909139,
#  1582711.0013362628,
#  2910179.764248607,
#  40044204.27077095,
#  2480483.239495963,
#  35080824.11021072,
#  2263802.2174139847,
#  8400988.586852442,
#  741279.4289077072,
#  3557207.4270088943,
#  5312281.260496842,
#  11243355.455244455,
#  2329831.5686416426,
#  2839231.51945035,
#  6859537.637734241,
#  ...]

# %% [markdown]
# # Calculating Y_true and Y_pred

# %%
Y_true = y_test

Y_pred = gbm_default.predict(X_test)
features = list(X_train)

# %% [markdown]
# # Registering the Model

# %%
register_model(
    gbm_default,
    score,
    "fifa_model",
    "fifa_regression",
    MLModelFlavours.sklearn,
    init_script="mkdir abc \\n cd abc \\n touch abc.txt",
    input_type="json",
    explain_ai=True,
    x_train=X_train, 
    y_train=y_train, 
    y_true=Y_true,
    y_pred=Y_pred,
    feature_names=features,
    feature_ids=features,
    target_names=["Value"],
    model_type="regression",
    kyd="True"
)
# Out:
# Calculating build time metrics
#
# Progress: ██████████████████████████████████████████████████████████████████████ 100.0%
# Publishing:   0%|          | 0/1 [00:00<?, ?it/s]
# Know Your Data for /6cd3afcf-b627-4b37-9da6-c807d2ad070c/6cd3afcf-b627-4b37-9da6-c807d2ad070c/ Published
# 2021-01-18 14:46:36,697 - skater.core.explanations - WARNING - Progress bars slow down runs by 10-20%. For slightly
# faster runs, do progressbar=False
# 2021-01-18 14:46:36,699 - skater.core.explanations - WARNING - Multiprocessing failed, going single process
# [25/25] grid cells ████████████████████ Time elapsed: 1 seconds
# 2021-01-18 14:46:38,650 - skater.core.explanations - WARNING - Progress bars slow down runs by 10-20%. For slightly
# faster runs, do progressbar=False
# 2021-01-18 14:46:38,652 - skater.core.explanations - WARNING - Multiprocessing failed, going single process
# [22/22] grid cells ████████████████████ Time elapsed: 1 seconds
# 2021-01-18 14:46:40,438 - skater.core.explanations - WARNING - Progress bars slow down runs by 10-20%. For slightly
# faster runs, do progressbar=False
# 2021-01-18 14:46:40,440 - skater.core.explanations - WARNING - Multiprocessing failed, going single process
# [22/22] grid cells ████████████████████ Time elapsed: 1 seconds
# 2021-01-18 14:46:42,201 - skater.core.explanations - WARNING - Progress bars slow down runs by 10-20%. For slightly
# faster runs, do progressbar=False
# 2021-01-18 14:46:42,203 - skater.core.explanations - WARNING - Multiprocessing failed, going single process
# [27/27] grid cells ████████████████████ Time elapsed: 1 seconds
# 2021-01-18 14:46:44,236 - skater.core.explanations - WARNING - Progress bars slow down runs by 10-20%. For slightly
# faster runs, do progressbar=False
# 2021-01-18 14:46:44,238 - skater.core.explanations - WARNING - Multiprocessing failed, going single process
# [29/29] grid cells ████████████████████ Time elapsed: 1 seconds
# 2021-01-18 14:46:46,285 - skater.core.explanations - WARNING - Progress bars slow down runs by 10-20%. For slightly
# faster runs, do progressbar=False
# 2021-01-18 14:46:46,287 - skater.core.explanations - WARNING - Multiprocessing failed, going single process
# [30/30] grid cells ████████████████████ Time elapsed: 1 seconds
# 2021-01-18 14:46:48,261 - skater.core.explanations - WARNING - Progress bars slow down runs by 10-20%. For slightly
# faster runs, do progressbar=False
# 2021-01-18 14:46:48,264 - skater.core.explanations - WARNING - Multiprocessing failed, going single process
# [30/30] grid cells ████████████████████ Time elapsed: 1 seconds
# 2021-01-18 14:46:50,362 - skater.core.explanations - WARNING - Progress bars slow down runs by 10-20%. For slightly
# faster runs, do progressbar=False
# 2021-01-18 14:46:50,364 - skater.core.explanations - WARNING - Multiprocessing failed, going single process
# [30/30] grid cells ████████████████████ Time elapsed: 1 seconds
# 2021-01-18 14:46:52,506 - skater.core.explanations - WARNING - Progress bars slow down runs by 10-20%. For slightly
# faster runs, do progressbar=False
# 2021-01-18 14:46:52,508 - skater.core.explanations - WARNING - Multiprocessing failed, going single process
# [27/27] grid cells ████████████████████ Time elapsed: 1 seconds
# 2021-01-18 14:46:54,342 - skater.core.explanations - WARNING - Progress bars slow down runs by 10-20%. For slightly
# faster runs, do progressbar=False
# 2021-01-18 14:46:54,344 - skater.core.explanations - WARNING - Multiprocessing failed, going single process
# [29/29] grid cells ████████████████████ Time elapsed: 1 seconds
# 2021-01-18 14:46:56,307 - skater.core.explanations - WARNING - Progress bars slow down runs by 10-20%. For slightly
# faster runs, do progressbar=False
# 2021-01-18 14:46:56,309 - skater.core.explanations - WARNING - Multiprocessing failed, going single process
# [29/29] grid cells ████████████████████ Time elapsed: 1 seconds
# 2021-01-18 14:46:58,193 - skater.core.explanations - WARNING - Progress bars slow down runs by 10-20%. For slightly
# faster runs, do progressbar=False
# 2021-01-18 14:46:58,195 - skater.core.explanations - WARNING - Multiprocessing failed, going single process
# [28/28] grid cells ████████████████████ Time elapsed: 1 seconds
# 2021-01-18 14:47:00,268 - skater.core.explanations - WARNING - Progress bars slow down runs by 10-20%. For slightly
# faster runs, do progressbar=False
# 2021-01-18 14:47:00,270 - skater.core.explanations - WARNING - Multiprocessing failed, going single process
# [13/13] grid cells ████████████████████ Time elapsed: 0 seconds
# 2021-01-18 14:47:01,614 - skater.core.explanations - WARNING - Progress bars slow down runs by 10-20%. For slightly
# faster runs, do progressbar=False
# 2021-01-18 14:47:01,617 - skater.core.explanations - WARNING - Multiprocessing failed, going single process
# [13/13] grid cells ████████████████████ Time elapsed: 0 seconds
# 2021-01-18 14:47:02,964 - skater.core.explanations - WARNING - Progress bars slow down runs by 10-20%. For slightly
# faster runs, do progressbar=False
# 2021-01-18 14:47:02,966 - skater.core.explanations - WARNING - Multiprocessing failed, going single process
# [24/24] grid cells ████████████████████ Time elapsed: 1 seconds
# 2021-01-18 14:47:04,711 - skater.core.explanations - WARNING - Progress bars slow down runs by 10-20%. For slightly
# faster runs, do progressbar=False
# 2021-01-18 14:47:04,714 - skater.core.explanations - WARNING - Multiprocessing failed, going single process
# [26/26] grid cells ████████████████████ Time elapsed: 1 seconds
# 2021-01-18 14:47:06,227 - skater.core.explanations - WARNING - Progress bars slow down runs by 10-20%. For slightly
# faster runs, do progress_bar=False
# 2021-01-18 14:47:06,230 - skater.core.explanations - WARNING - Multiprocessing failed, going single process
# [16/16] features ████████████████████ Time elapsed: 3 seconds
# 2021-01-18 14:47:10,209 - skater.core.global_interpretation.tree_surrogate - INFO - post pruning applied ...
# 2021-01-18 14:47:10,235 - skater.core.global_interpretation.tree_surrogate - INFO - Scorer used MAE
# 2021-01-18 14:47:10,236 - skater.core.global_interpretation.tree_surrogate - INFO - original score using base model 516013.78608318244
# 2021-01-18 14:47:10,351 - skater.core.global_interpretation.tree_surrogate - INFO - Summary: childrens of the following nodes are removed []
# 2021-01-18 14:47:10,354 - skater.core.global_interpretation.tree_surrogate - INFO - Done generating prediction using the surrogate, shape (3750,)
# 2021-01-18 14:47:10,355 - skater.core.global_interpretation.tree_surrogate - INFO - Done scoring, surrogate score 516013.786; oracle score 324673.818
# {'created_by': 'devesh.surve@lntinfotech.com',
#  'created_on': '2021-01-12T07:13:34+00:00',
#  'deploymentstatus': False,
#  'description': 'fifa_regression',
#  'flavour': 'sklearn',
#  'id': '3a0111cd-07d7-46ab-bc0d-d169c8f3e846',
#  'last_modified_by': 'devesh.surve@lntinfotech.com',
#  'last_modified_on': '2021-01-12T07:13:34+00:00',
#  'model_display': True,
#  'name': 'fifa_model',
#  'project_id': '35ada3e3-00f5-4ad8-a462-58269dd03a9f',
#  'source': None,
#  'tags': None,
#  'type': 'model',
#  'versions': [{'created_by': 'devesh.surve@lntinfotech.com',
#    'created_on': '2021-01-12T10:31:16+00:00',
#    'datasource_name': '',
#    'dependent_model': None,
#    'deploy_info': None,
#    'deployments': [],
#    'description': None,
#    'docker_image_url': 'registry.lti-aiq.in:443/mosaic-ai-logistics/mosaic-ai-serving:1.0.0-30092020',
#    'gpu_docker_image_url': 'registry.lti-aiq.in:443/mosaic-ai-logistics/mosaic-ai-serving:gpu-1.0.0-29102020',
#    'id': '10477031-65cf-4521-894d-8a81010b3063',
#    'init_script': '"pip install --user absl-py==0.11.0\\n pip install --user alembic==1.4.3\\n pip install --user astor==0.8.1\\n pip install --user astroid==2.3.3\\n pip install --user async-generator==1.10\\n pip install --user attrs==19.3.0\\n pip install --user backcall==0.2.0\\n pip install --user beautifulsoup4==4.9.3\\n pip install --user bleach==3.1.5\\n pip install --user blis==0.4.1\\n pip install --user bokeh==2.1.1\\n pip install --user bs4==0.0.1\\n pip install --user cached-property==1.5.2\\n pip install --user cachetools==4.1.1\\n pip install --user category-encoders==2.2.2\\n pip install --user certifi==2020.6.20\\n pip install --user chardet==3.0.4\\n pip install --user click==7.1.2\\n pip install --user cloudpickle==1.2.2\\n pip install --user colorama==0.4.4\\n pip install --user commonmark==0.9.1\\n pip install --user coverage==5.3\\n pip install --user cycler==0.10.0\\n pip install --user cymem==2.0.4\\n pip install --user dalex==1.0.0\\n pip install --user dask==2.30.0\\n pip install --user dataclasses==0.7\\n pip install --user deap==1.3.1\\n pip install --user decorator==4.4.2\\n pip install --user defusedxml==0.6.0\\n pip install --user dill==0.3.3\\n pip install --user ds-lime==0.1.1.27\\n pip install --user entrypoints==0.3\\n pip install --user flasgger==0.9.3\\n pip install --user Flask==1.1.1\\n pip install --user Flask-Cors==3.0.8\\n pip install --user Flask-SQLAlchemy==2.4.3\\n pip install --user fonttools==4.16.1\\n pip install --user future==0.18.2\\n pip install --user gast==0.4.0\\n pip install --user google-auth==1.23.0\\n pip install --user google-pasta==0.2.0\\n pip install --user grpcio==1.33.2\\n pip install --user gunicorn==19.9.0\\n pip install --user h5py==3.0.0\\n pip install --user holoviews==1.13.5\\n pip install --user idna==2.8\\n pip install --user importlib-metadata==1.7.0\\n pip install --user iniconfig==1.1.1\\n pip install --user ipykernel==5.3.1\\n pip install --user ipyplot==1.1.0\\n pip install --user ipython==7.16.1\\n pip install --user ipython-genutils==0.2.0\\n pip install --user ipywidgets==7.5.1\\n pip install --user isort==4.3.21\\n pip install --user itsdangerous==1.1.0\\n pip install --user jedi==0.17.1\\n pip install --user Jinja2==2.11.2\\n pip install --user joblib==0.11\\n pip install --user jsonpickle==1.2\\n pip install --user jsonschema==2.6.0\\n pip install --user jupyter==1.0.0\\n pip install --user jupyter-client==6.1.5\\n pip install --user jupyter-console==6.1.0\\n pip install --user jupyter-contrib-core==0.3.3\\n pip install --user jupyter-contrib-nbextensions==0.5.1\\n pip install --user jupyter-core==4.6.3\\n pip install --user jupyter-highlight-selected-word==0.2.0\\n pip install --user jupyter-latex-envs==1.4.6\\n pip install --user jupyter-nbextensions-configurator==0.4.1\\n pip install --user jupyterhub==0.9.4\\n pip install --user Keras==2.2.4\\n pip install --user Keras-Applications==1.0.8\\n pip install --user Keras-Preprocessing==1.1.2\\n pip install --user kiwisolver==1.3.1\\n pip install --user kubernetes==9.0.0\\n pip install --user kyd==0.1.8\\n pip install --user lazy-object-proxy==1.4.3\\n pip install --user lightgbm==3.1.1\\n pip install --user lxml==4.6.1\\n pip install --user Mako==1.1.3\\n pip install --user Markdown==3.3.3\\n pip install --user MarkupSafe==1.1.1\\n pip install --user matplotlib==3.1.1\\n pip install --user mccabe==0.6.1\\n pip install --user minio==4.0.18\\n pip install --user mistune==0.8.4\\n pip install --user multiprocess==0.70.11.1\\n pip install --user murmurhash==1.0.4\\n pip install --user mysql-connector-python==8.0.17\\n pip install --user mysql-connector-python-rf==2.2.2\\n pip install --user nbconvert==5.6.1\\n pip install --user nbformat==5.0.7\\n pip install --user networkx==2.5\\n pip install --user nltk==3.5\\n pip install --user nose==1.3.7\\n pip install --user notebook==5.7.0\\n pip install --user numpy==1.19.5\\n pip install --user oauthlib==3.1.0\\n pip install --user opencv-python==4.2.0.34 ...
#    'input_type': 'json',
#    'last_modified_by': 'devesh.surve@lntinfotech.com',
#    'last_modified_on': '2021-01-12T10:31:19+00:00',
#    'metadata_info': None,
#    'ml_model_id': '3a0111cd-07d7-46ab-bc0d-d169c8f3e846',
#    'model_class': {'base_estimator': "DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,\n                      max_leaf_nodes=None, min_impurity_decrease=0.0,\n                      min_impurity_split=None, min_samples_leaf=1,\n                      min_samples_split=2, min_weight_fraction_leaf=0.0,\n                      presort=False, random_state=None, splitter='best')",
#     'base_estimator_': "DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,\n                      max_leaf_nodes=None, min_impurity_decrease=0.0,\n                      min_impurity_split=None, min_samples_leaf=1,\n                      min_samples_split=2, min_weight_fraction_leaf=0.0,\n                      presort=False, random_state=None, splitter='best')",
#     'bootstrap': True,
#     'class': 'sklearn.ensemble.forest.RandomForestRegressor',
#     'class_weight': None,
#     'criterion': 'mse',
#     'estimator_params': ['criterion',
#      'max_depth',
#      'min_samples_split',
#      'min_samples_leaf',
#      'min_weight_fraction_leaf',
#      'max_features',
#      'max_leaf_nodes',
#      'min_impurity_decrease',
#      'min_impurity_split',
#      'random_state'],
#     'estimators_': ["DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',\n                      max_leaf_nodes=None, min_impurity_decrease=0.0,\n                      min_impurity_split=None, min_samples_leaf=1,\n                      min_samples_split=2, min_weight_fraction_leaf=0.0,\n                      presort=False, random_state=700076895, splitter='best')",
#      "DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',\n                      max_leaf_nodes=None, min_impurity_decrease=0.0,\n                      min_impurity_split=None, min_samples_leaf=1,\n                      min_samples_split=2, min_weight_fraction_leaf=0.0,\n                      presort=False, random_state=2009947354, splitter='best')",
#      "DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',\n                      max_leaf_nodes=None, min_impurity_decrease=0.0,\n                      min_impurity_split=None, min_samples_leaf=1,\n                      min_samples_split=2, min_weight_fraction_leaf=0.0,\n                      presort=False, random_state=1351467828, splitter='best')",
#      "DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',\n                      max_leaf_nodes=None, min_impurity_decrease=0.0,\n                      min_impurity_split=None, min_samples_leaf=1,\n                      min_samples_split=2, min_weight_fraction_leaf=0.0,\n                      presort=False, random_state=418495305, splitter='best')",
#      "DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',\n                      max_leaf_nodes=None, min_impurity_decrease=0.0,\n                      min_impurity_split=None, min_samples_leaf=1,\n                      min_samples_split=2, min_weight_fraction_leaf=0.0,\n                      presort=False, random_state=1893145886, splitter='best')",
#      "DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',\n                      max_leaf_nodes=None, min_impurity_decrease=0.0,\n                      min_impurity_split=None, min_samples_leaf=1,\n                      min_samples_split=2, min_weight_fraction_leaf=0.0,\n                      presort=False, random_state=2040444913, splitter='best')",
#      "DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',\n                      max_leaf_nodes=None, min_impurity_decrease=0.0,\n                      min_impurity_split=None, min_samples_leaf=1,\n                      min_samples_split=2, min_weight_fraction_leaf=0.0,\n                      presort=False, random_state=1445423451, splitter='best')",
#      "DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',\n                      max_leaf_nodes=None, min_impurity_decrease=0.0,\n                      min_impurity_split=None, min_samples_leaf=1,\n                      min_samples_split=2, min_weight_fraction_leaf=0.0,\n                      presort=False, random_state=1518888293, splitter='best')",
#      "DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',\n                      max_leaf_nodes=None, min_impurity_decrease=0.0,\n                      min_impurity_split=None, min_samples_leaf=1,\n                      min_samples_split=2, min_weight_fraction_leaf=0.0,\n                      presort=False, random_state=1419655046, splitter='best')",
#      "DecisionTreeRegressor(criterion='mse', max_depth=None, max_features='auto',\n                      max_leaf_nodes=None, min_impurity_decrease=0.0,\n                      min_impurity_split=None, min_samples_leaf=1,\n                      min_samples_split=2, min_weight_fraction_leaf=0.0,\n                      presort=False, random_state=1089780766, splitter='best')"],
#     'max_depth': None,
#     'max_features': 'auto',
#     'max_leaf_nodes': None,
#     'min_impurity_decrease': 0,
#     'min_impurity_split': None,
#     'min_samples_leaf': 1,
#     'min_samples_split': 2,
#     'min_weight_fraction_leaf': 0,
#     'n_estimators': 10,
#     'n_features_': 16,
#     'n_jobs': None,
#     'n_outputs_': 1,
#     'oob_score': False,
#     'random_state': None,
#     'verbose': 0,
#     'warm_start': False},
#    'model_info': {'deep_learning_model': False,
#     'feature_names': ['age',
#      'height_cm',
#      'weight_kg',
#      'skill_dribbling',
#      'attacking_crossing',
#      'attacking_finishing',
#      'movement_acceleration',
#      'movement_sprint_speed',
#      'power_shot_power',
#      'mentality_aggression',
#      'defending_marking',
#      'defending_standing_tackle',
#      'goalkeeping_diving',
#      'goalkeeping_handling',
#      'overall',
#      'potential'],
#     'min_max_features': [{'data_type': 'numerical',
#       'feature_name': 'age',
#       'max': 41,
#       'min': 16},
#      {'data_type': 'numerical',
#       'feature_name': 'height_cm',
#       'max': 203,
#       'min': 156},
#      {'data_type': 'numerical',
#       'feature_name': 'weight_kg',
#       'max': 103,
#       'min': 52},
#      {'data_type': 'numerical',
#       'feature_name': 'skill_dribbling',
#       'max': 97,
#       'min': 7},
#      {'data_type': 'numerical',
#       'feature_name': 'attacking_crossing',
#       'max': 93,
#       'min': 6},
#      {'data_type': 'numerical',
#       'feature_name': 'attacking_finishing',
#       'max': 95,
#       'min': 5},
#      {'data_type': 'numerical',
#       'feature_name': 'movement_acceleration',
#       'max': 96,
#       'min': 17},
#      {'data_type': 'numerical',
#       'feature_name': 'movement_sprint_speed',
#       'max': 96,
#       'min': 15},
#      {'data_type': 'numerical',
#       'feature_name': 'power_shot_power',
#       'max': 95,
#       'min': 15},
#      {'data_type': 'numerical',
#       'feature_name': 'mentality_aggression',
#       'max': 94,
#       'min': 11},
#      {'data_type': 'numerical',
#       'feature_name': 'defending_marking',
#       'max': 94,
#       'min': 7},
#      {'data_type': 'numerical',
#       'feature_name': 'defending_standing_tackle',
#       'max': 92,
#       'min': 8},
#      {'data_type': 'numerical',
#       'feature_name': 'goalkeeping_diving',
#       'max': 90,
#       'min': 1},
#      {'data_type': 'numerical',
#       'feature_name': 'goalkeeping_handling',
#       'max': 92,
#       'min': 1},
#      {'data_type': 'numerical',
#       'feature_name': 'overall',
#       'max': 94,
#       'min': 70},
#      {'data_type': 'numerical',
#       'feature_name': 'potential',
#       'max': 95,
#       'min': 70}],
#     'mode': 'regression',
#     'number_of_features': 16,
#     'target_names': ['Value'],
#     'temp_dir': ''},
#    'object_url': '3a0111cd-07d7-46ab-bc0d-d169c8f3e846/10477031-65cf-4521-894d-8a81010b3063/ml_model.tar.gz',
#    'profiling': [],
#    'schema': {},
#    'status': 'active',
#    'target_names': {'target': ['Value']},
#    'version_no': 2},
#   {'created_by': 'devesh.surve@lntinfotech.com',
#    'created_on': '2021-01-12T07:13:34+00:00',
#    'datasource_name': '',
#    'dependent_model': None,
#    'deploy_info': None,
#    'deployments': [],
#    'description': None,
#    'docker_image_url': 'registry.lti-aiq.in:443/mosaic-ai-logistics/mosaic-ai-serving:1.0.0-30092020',
#    'gpu_docker_image_url': 'registry.lti-aiq.in:443/mosaic-ai-logistics/mosaic-ai-serving:gpu-1.0.0-29102020',
#    'id': '54e4a277-145b-4cd1-896e-f0f55f41c5fa',
#    'init_script': '"pip install --user absl-py==0.11.0\\n pip install --user alembic==1.4.3\\n pip install --user astor==0.8.1\\n pip install --user astroid==2.3.3\\n pip install --user async-generator==1.10\\n pip install --user attrs==19.3.0\\n pip install --user backcall==0.2.0\\n pip install --user beautifulsoup4==4.9.3\\n pip install --user bleach==3.1.5\\n pip install --user blis==0.4.1\\n pip install --user bokeh==2.1.1\\n pip install --user bs4==0.0.1\\n pip install --user cached-property==1.5.2\\n pip install --user cachetools==4.1.1\\n pip install --user category-encoders==2.2.2\\n pip install --user certifi==2020.6.20\\n pip install --user chardet==3.0.4\\n pip install --user click==7.1.2\\n pip install --user cloudpickle==1.2.2\\n pip install --user colorama==0.4.4\\n pip install --user commonmark==0.9.1\\n pip install --user coverage==5.3\\n pip install --user cycler==0.10.0\\n pip install --user cymem==2.0.4\\n pip install --user dalex==1.0.0\\n pip install --user dask==2.30.0\\n pip install --user dataclasses==0.7\\n pip install --user deap==1.3.1\\n pip install --user decorator==4.4.2\\n pip install --user defusedxml==0.6.0\\n pip install --user dill==0.3.3\\n pip install --user ds-lime==0.1.1.27\\n pip install --user entrypoints==0.3\\n pip install --user flasgger==0.9.3\\n pip install --user Flask==1.1.1\\n pip install --user Flask-Cors==3.0.8\\n pip install --user Flask-SQLAlchemy==2.4.3\\n pip install --user fonttools==4.16.1\\n pip install --user future==0.18.2\\n pip install --user gast==0.4.0\\n pip install --user google-auth==1.23.0\\n pip install --user google-pasta==0.2.0\\n pip install --user grpcio==1.33.2\\n pip install --user gunicorn==19.9.0\\n pip install --user h5py==3.0.0\\n pip install --user holoviews==1.13.5\\n pip install --user idna==2.8\\n pip install --user importlib-metadata==1.7.0\\n pip install --user iniconfig==1.1.1\\n pip install --user ipykernel==5.3.1\\n pip install --user ipyplot==1.1.0\\n pip install --user ipython==7.16.1\\n pip install --user ipython-genutils==0.2.0\\n pip install --user ipywidgets==7.5.1\\n pip install --user isort==4.3.21\\n pip install --user itsdangerous==1.1.0\\n pip install --user jedi==0.17.1\\n pip install --user Jinja2==2.11.2\\n pip install --user joblib==0.11\\n pip install --user jsonpickle==1.2\\n pip install --user jsonschema==2.6.0\\n pip install --user jupyter==1.0.0\\n pip install --user jupyter-client==6.1.5\\n pip install --user jupyter-console==6.1.0\\n pip install --user jupyter-contrib-core==0.3.3\\n pip install --user jupyter-contrib-nbextensions==0.5.1\\n pip install --user jupyter-core==4.6.3\\n pip install --user jupyter-highlight-selected-word==0.2.0\\n pip install --user jupyter-latex-envs==1.4.6\\n pip install --user jupyter-nbextensions-configurator==0.4.1\\n pip install --user jupyterhub==0.9.4\\n pip install --user Keras==2.2.4\\n pip install --user Keras-Applications==1.0.8\\n pip install --user Keras-Preprocessing==1.1.2\\n pip install --user kiwisolver==1.3.1\\n pip install --user kubernetes==9.0.0\\n pip install --user kyd==0.1.8\\n pip install --user lazy-object-proxy==1.4.3\\n pip install --user lightgbm==3.1.1\\n pip install --user lxml==4.6.1\\n pip install --user Mako==1.1.3\\n pip install --user Markdown==3.3.3\\n pip install --user MarkupSafe==1.1.1\\n pip install --user matplotlib==3.1.1\\n pip install --user mccabe==0.6.1\\n pip install --user minio==4.0.18\\n pip install --user mistune==0.8.4\\n pip install --user multiprocess==0.70.11.1\\n pip install --user murmurhash==1.0.4\\n pip install --user mysql-connector-python==8.0.17\\n pip install --user mysql-connector-python-rf==2.2.2\\n pip install --user nbconvert==5.6.1\\n pip install --user nbformat==5.0.7\\n pip install --user networkx==2.5\\n pip install --user nltk==3.5\\n pip install --user nose==1.3.7\\n pip install --user notebook==5.7.0\\n pip install --user numpy==1.19.5\\n pip install --user oauthlib==3.1.0\\n pip install --user opencv-python==4.2.0.34 ...
#    'input_type': 'json',
#    'last_modified_by': 'devesh.surve@lntinfotech.com',
#    'last_modified_on': '2021-01-12T07:13:36+00:00',
#    'metadata_info': None,
#    'ml_model_id': '3a0111cd-07d7-46ab-bc0d-d169c8f3e846',
#    'model_class': {'_rng': 'RandomState(MT19937)',
#     'alpha': 0.9,
#     'class': 'sklearn.ensemble.gradient_boosting.GradientBoostingRegressor',
#     'criterion': 'friedman_mse',
#     'estimators_': None,
#     'init': None,
#     'init_': "DummyRegressor(constant=None, quantile=None, strategy='mean')",
#     'learning_rate': 0.1,
#     'loss': 'ls',
#     'loss_': '<sklearn.ensemble._gb_losses.LeastSquaresError object at 0x7fc9d9223d68>',
#     'max_depth': 3,
#     'max_features': None,
#     'max_features_': 16,
#     'max_leaf_nodes': None,
#     'min_impurity_decrease': 0,
#     'min_impurity_split': None,
#     'min_samples_leaf': 1,
#     'min_samples_split': 2,
#     'min_weight_fraction_leaf': 0,
#     'n_classes_': 1,
#     'n_estimators': 100,
#     'n_estimators_': 100,
#     'n_features_': 16,
#     'n_iter_no_change': None,
#     'presort': 'auto',
#     'random_state': None,
#     'subsample': 1,
#     'tol': 0.0001,
#     'train_score_': None,
#     'validation_fraction': 0.1,
#     'verbose': 0,
#     'warm_start': False},
#    'model_info': {'deep_learning_model': False,
#     'feature_names': ['age',
#      'height_cm',
#      'weight_kg',
#      'skill_dribbling',
#      'attacking_crossing',
#      'attacking_finishing',
#      'movement_acceleration',
#      'movement_sprint_speed',
#      'power_shot_power',
#      'mentality_aggression',
#      'defending_marking',
#      'defending_standing_tackle',
#      'goalkeeping_diving',
#      'goalkeeping_handling',
#      'overall',
#      'potential'],
#     'min_max_features': [{'data_type': 'numerical',
#       'feature_name': 'age',
#       'max': 41,
#       'min': 16},
#      {'data_type': 'numerical',
#       'feature_name': 'height_cm',
#       'max': 203,
#       'min': 156},
#      {'data_type': 'numerical',
#       'feature_name': 'weight_kg',
#       'max': 103,
#       'min': 52},
#      {'data_type': 'numerical',
#       'feature_name': 'skill_dribbling',
#       'max': 97,
#       'min': 7},
#      {'data_type': 'numerical',
#       'feature_name': 'attacking_crossing',
#       'max': 93,
#       'min': 6},
#      {'data_type': 'numerical',
#       'feature_name': 'attacking_finishing',
#       'max': 95,
#       'min': 5},
#      {'data_type': 'numerical',
#       'feature_name': 'movement_acceleration',
#       'max': 96,
#       'min': 17},
#      {'data_type': 'numerical',
#       'feature_name': 'movement_sprint_speed',
#       'max': 96,
#       'min': 15},
#      {'data_type': 'numerical',
#       'feature_name': 'power_shot_power',
#       'max': 95,
#       'min': 15},
#      {'data_type': 'numerical',
#       'feature_name': 'mentality_aggression',
#       'max': 94,
#       'min': 11},
#      {'data_type': 'numerical',
#       'feature_name': 'defending_marking',
#       'max': 94,
#       'min': 7},
#      {'data_type': 'numerical',
#       'feature_name': 'defending_standing_tackle',
#       'max': 92,
#       'min': 8},
#      {'data_type': 'numerical',
#       'feature_name': 'goalkeeping_diving',
#       'max': 90,
#       'min': 1},
#      {'data_type': 'numerical',
#       'feature_name': 'goalkeeping_handling',
#       'max': 92,
#       'min': 1},
#      {'data_type': 'numerical',
#       'feature_name': 'overall',
#       'max': 94,
#       'min': 70},
#      {'data_type': 'numerical',
#       'feature_name': 'potential',
#       'max': 95,
#       'min': 70}],
#     'mode': 'regression',
#     'number_of_features': 16,
#     'target_names': ['Value'],
#     'temp_dir': ''},
#    'object_url': '3a0111cd-07d7-46ab-bc0d-d169c8f3e846/54e4a277-145b-4cd1-896e-f0f55f41c5fa/ml_model.tar.gz',
#    'profiling': [],
#    'schema': {},
#    'status': 'active',
#    'target_names': {'target': ['Value']},
#    'version_no': 1},
#   {'created_by': 'devesh.surve@lntinfotech.com',
#    'created_on': '2021-01-18T14:46:27+00:00',
#    'datasource_name': '',
#    'dependent_model': None,
#    'deploy_info': None,
#    'deployments': [],
#    'description': None,
#    'docker_image_url': 'registry.lti-aiq.in:443/mosaic-ai-logistics/mosaic-ai-serving:1.0.0-07122021',
#    'gpu_docker_image_url': 'registry.lti-aiq.in:443/mosaic-ai-logistics/mosaic-ai-serving:gpu-1.0.0-07122021',
#    'id': '6cd3afcf-b627-4b37-9da6-c807d2ad070c',
#    'init_script': '"pip install --user absl-py==0.11.0\\n pip install --user alembic==1.4.3\\n pip install --user alibi-detect==0.4.4\\n pip install --user argon2-cffi==20.1.0\\n pip install --user astor==0.8.1\\n pip install --user astroid==2.3.3\\n pip install --user astunparse==1.6.3\\n pip install --user async-generator==1.10\\n pip install --user attrs==20.3.0\\n pip install --user backcall==0.2.0\\n pip install --user beautifulsoup4==4.9.3\\n pip install --user bleach==3.2.1\\n pip install --user blis==0.4.1\\n pip install --user bokeh==2.1.1\\n pip install --user bs4==0.0.1\\n pip install --user cached-property==1.5.2\\n pip install --user cachetools==4.2.0\\n pip install --user category-encoders==2.2.2\\n pip install --user certifi==2020.12.5\\n pip install --user cffi==1.14.4\\n pip install --user chardet==3.0.4\\n pip install --user click==7.1.2\\n pip install --user cloudpickle==1.6.0\\n pip install --user colorama==0.4.4\\n pip install --user colorcet==2.0.2\\n pip install --user commonmark==0.9.1\\n pip install --user creme==0.6.1\\n pip install --user cycler==0.10.0\\n pip install --user cymem==2.0.5\\n pip install --user dask==2021.1.0\\n pip install --user dataclasses==0.8\\n pip install --user deap==1.3.1\\n pip install --user decorator==4.4.2\\n pip install --user defusedxml==0.6.0\\n pip install --user dill==0.3.3\\n pip install --user dm-tree==0.1.5\\n pip install --user ds-lime==0.1.1.27\\n pip install --user entrypoints==0.3\\n pip install --user filelock==3.0.12\\n pip install --user flasgger==0.9.3\\n pip install --user Flask==1.1.1\\n pip install --user Flask-Cors==3.0.8\\n pip install --user Flask-SQLAlchemy==2.4.4\\n pip install --user flatbuffers==1.12\\n pip install --user fonttools==4.18.2\\n pip install --user future==0.18.2\\n pip install --user gast==0.4.0\\n pip install --user google-auth==1.24.0\\n pip install --user google-auth-oauthlib==0.4.2\\n pip install --user google-pasta==0.2.0\\n pip install --user grpcio==1.32.0\\n pip install --user gunicorn==19.9.0\\n pip install --user h5py==2.10.0\\n pip install --user holoviews==1.14.1\\n pip install --user idna==2.8\\n pip install --user imageio==2.9.0\\n pip install --user importlib-metadata==3.3.0\\n pip install --user ipykernel==5.4.2\\n pip install --user ipyplot==1.1.0\\n pip install --user ipython==7.16.1\\n pip install --user ipython-genutils==0.2.0\\n pip install --user ipywidgets==7.6.3\\n pip install --user isort==4.3.21\\n pip install --user itsdangerous==1.1.0\\n pip install --user jedi==0.18.0\\n pip install --user Jinja2==2.11.2\\n pip install --user joblib==0.11\\n pip install --user jsonpickle==1.2\\n pip install --user jsonschema==2.6.0\\n pip install --user jupyter==1.0.0\\n pip install --user jupyter-client==6.1.7\\n pip install --user jupyter-console==6.2.0\\n pip install --user jupyter-contrib-core==0.3.3\\n pip install --user jupyter-contrib-nbextensions==0.5.1\\n pip install --user jupyter-core==4.7.0\\n pip install --user jupyter-highlight-selected-word==0.2.0\\n pip install --user jupyter-latex-envs==1.4.6\\n pip install --user jupyter-nbextensions-configurator==0.4.1\\n pip install --user jupyterhub==0.9.4\\n pip install --user jupyterlab-pygments==0.1.2\\n pip install --user jupyterlab-widgets==1.0.0\\n pip install --user Keras==2.2.4\\n pip install --user Keras-Applications==1.0.8\\n pip install --user Keras-Preprocessing==1.1.2\\n pip install --user kiwisolver==1.3.1\\n pip install --user kubernetes==9.0.0\\n pip install --user kyd==0.1.8\\n pip install --user lazy-object-proxy==1.4.3\\n pip install --user lxml==4.6.2\\n pip install --user Mako==1.1.4\\n pip install --user Markdown==3.3.3\\n pip install --user MarkupSafe==1.1.1\\n pip install --user matplotlib==3.1.1\\n pip install --user mccabe==0.6.1\\n pip install --user minio==4.0.18\\n pip install --user mistune==0.8.4\\n pip install --user mmh3==2.5.1\\n pip install --user multiprocess==0.70.11.1\\n pip install --user murmurhash==1.0.5\\n pip install --user m ...
#    'input_type': 'json',
#    'last_modified_by': 'devesh.surve@lntinfotech.com',
#    'last_modified_on': '2021-01-18T14:46:36+00:00',
#    'metadata_info': None,
#    'ml_model_id': '3a0111cd-07d7-46ab-bc0d-d169c8f3e846',
#    'model_class': {'_rng': '<mtrand.RandomState object at 0x7f502c0e4798>',
#     'alpha': 0.9,
#     'class': 'sklearn.ensemble.gradient_boosting.GradientBoostingRegressor',
#     'criterion': 'friedman_mse',
#     'estimators_': None,
#     'init': None,
#     'init_': '<sklearn.ensemble.gradient_boosting.MeanEstimator object at 0x7f4fdc4206a0>',
#     'learning_rate': 0.1,
#     'loss': 'ls',
#     'loss_': '<sklearn.ensemble.gradient_boosting.LeastSquaresError object at 0x7f4fdc420438>',
#     'max_depth': 3,
#     'max_features': None,
#     'max_features_': 16,
#     'max_leaf_nodes': None,
#     'min_impurity_decrease': 0,
#     'min_impurity_split': None,
#     'min_samples_leaf': 1,
#     'min_samples_split': 2,
#     'min_weight_fraction_leaf': 0,
#     'n_classes_': 1,
#     'n_estimators': 100,
#     'n_estimators_': 100,
#     'n_features_': 16,
#     'n_iter_no_change': None,
#     'presort': 'auto',
#     'random_state': None,
#     'subsample': 1,
#     'tol': 0.0001,
#     'train_score_': None,
#     'validation_fraction': 0.1,
#     'verbose': 0,
#     'warm_start': False},
#    'model_info': {'deep_learning_model': False,
#     'feature_names': ['age',
#      'height_cm',
#      'weight_kg',
#      'skill_dribbling',
#      'attacking_crossing',
#      'attacking_finishing',
#      'movement_acceleration',
#      'movement_sprint_speed',
#      'power_shot_power',
#      'mentality_aggression',
#      'defending_marking',
#      'defending_standing_tackle',
#      'goalkeeping_diving',
#      'goalkeeping_handling',
#      'overall',
#      'potential'],
#     'min_max_features': [{'data_type': 'numerical',
#       'feature_name': 'age',
#       'max': 41,
#       'min': 16},
#      {'data_type': 'numerical',
#       'feature_name': 'height_cm',
#       'max': 203,
#       'min': 156},
#      {'data_type': 'numerical',
#       'feature_name': 'weight_kg',
#       'max': 103,
#       'min': 52},
#      {'data_type': 'numerical',
#       'feature_name': 'skill_dribbling',
#       'max': 97,
#       'min': 7},
#      {'data_type': 'numerical',
#       'feature_name': 'attacking_crossing',
#       'max': 93,
#       'min': 6},
#      {'data_type': 'numerical',
#       'feature_name': 'attacking_finishing',
#       'max': 95,
#       'min': 5},
#      {'data_type': 'numerical',
#       'feature_name': 'movement_acceleration',
#       'max': 96,
#       'min': 17},
#      {'data_type': 'numerical',
#       'feature_name': 'movement_sprint_speed',
#       'max': 96,
#       'min': 15},
#      {'data_type': 'numerical',
#       'feature_name': 'power_shot_power',
#       'max': 95,
#       'min': 15},
#      {'data_type': 'numerical',
#       'feature_name': 'mentality_aggression',
#       'max': 94,
#       'min': 11},
#      {'data_type': 'numerical',
#       'feature_name': 'defending_marking',
#       'max': 94,
#       'min': 7},
#      {'data_type': 'numerical',
#       'feature_name': 'defending_standing_tackle',
#       'max': 92,
#       'min': 8},
#      {'data_type': 'numerical',
#       'feature_name': 'goalkeeping_diving',
#       'max': 90,
#       'min': 1},
#      {'data_type': 'numerical',
#       'feature_name': 'goalkeeping_handling',
#       'max': 92,
#       'min': 1},
#      {'data_type': 'numerical',
#       'feature_name': 'overall',
#       'max': 94,
#       'min': 70},
#      {'data_type': 'numerical',
#       'feature_name': 'potential',
#       'max': 95,
#       'min': 70}],
#     'mode': 'regression',
#     'number_of_features': 16,
#     'target_names': ['Value'],
#     'temp_dir': ''},
#    'object_url': '3a0111cd-07d7-46ab-bc0d-d169c8f3e846/6cd3afcf-b627-4b37-9da6-c807d2ad070c/ml_model.tar.gz',
#    'profiling': [],
#    'schema': {},
#    'status': 'active',
#    'target_names': {'target': ['Value']},
#    'version_no': 3,
#    'detailed_matrix': '{"tag": "detailed_matrix", "model_metric_value": {"Explained Variance Score": 0.9893810219089159, "Mean Absolute Error": 380209.69706770766, "Mean Absolute Percentage Error": 6.4374639254100074, "Mean Squared Error": 792470860149.3123, "Root Mean Square Error": 890208.3240170877, "Root Mean Squared Logarithmic Error": null, "R2 score": 0.9893784221977242}}'}]}
