# %%
# !curl -H "Metadata-Flavor: Google" http://169.254.169.254/computeMetadata/v1/instance/service-accounts/default/token
# Out:
# {"access_token":"ya29.c.c0AY_VpZiWweZFp26Dkz4nDO35TGTR5UELrBhLwCnovFESiqFFvYf8raJxqAg3qxZTUCgvt80RsQr1xtWIVb8y1Xzy85-uPJP_yuzYcfu2lxMeLDn4HwU6-GFZaPxhzlvNrdkSNi9K8CEQYcnszsqIONwg_QZ4lRhRyD_7KR8K4ACxjigV2SxBJP4gWXw1wliO2zs8EE5X5iWjA51NWLuz4c-aVKQwflBpqG5dRoCLBDb1b4j3WKVBxFEjzcefsAC1C0wlGULrrFvX1kLbduMSpST_6Cosc3aViHUWAZrT-GbcOubBBHTtWmz9uIpSigCrB2AeT3Hkhz8US55ZHzWbbElG0NFripfFb-Mc1NZQXMHxqABkWYy2L9od8RQMC3j9E8UMp0qrion8EJj-IBTALPq97Yt9jHsPSuJjEUY3b8ZMCLZ4j6r_mVtao9r0vokqfPl5DEuCLWKnI9JfMkk_aayC8tltn3BLLs1GTkUdXqjFVrtz9MrjKhXiT9HNEdJgcePEUrVP20eSf0BCbVsCKN-FdvKiTIKqGD8t1cK97uAiujexku1VBGTfCaEGkA5OuAE0o66k_qUanatgeCFgZLz859-AXaYhWgU-zUszT625K6Mj6eMrx95wn4c_U4ZOrSyehg8zxfmaBIJuBZ_6wQ2R7n6k7fYQB-k0Bdiyl0qxy-B7r9Rdm2tuz1v9vjmFid_xmzyf216_a8fMmqx45jkmI8wtZX0UsmrRXRfSm_oSc2YMm3SJx-2p4sIpQ-hzbe-YYymzmFUcwlrt66cYcoss8zsiFzYBiVIBUI6XgxBp-I8BwY3rOjBher1JXjY4uIflVOZpbff6_Shs82e4isQ0nzy0XopVRgdhvpcB1losO9fYUn9nVy16vjQsVlqQw5W6bM62r_zhwpOvyy90MZVcJBMVJU4W1tvxwfrXJJXVvBz_2t2loOj0w35m5x4WsvUrX4c1lo0ohbhbyp1W7caUyfiUQzi2eleQrRXbqke10aIeSW0rew6","expires_in":3599,"token_type":"Bearer"}

# %%
import google.auth
import requests
from datetime import datetime, timedelta
from urllib.parse import quote

# # Get credentials
# credentials, _ = google.auth.default(scopes=["https://www.googleapis.com/auth/cloud-platform"])
# print('ss')
# print(credentials)
# print('ss')

# Define the project ID
project_id = "fdc-development-408605"

# Define the current time and interval
end_time = datetime.utcnow()
start_time = end_time - timedelta(hours=2)
print("end_time", end_time)
new_end_time = end_time.strftime("%Y-%m-%dT%H:%M:%SZ")
print("new_end_time", new_end_time)

# Define filter string
filter_str = 'resource.type="k8s_pod" AND resource.label."pod_name"="jy-75276912-5911-41bc-a7d2-22787407cc5c-sunny10683796ltimindt" AND metric.type="kubernetes.io/container/cpu/usage"'
encoded_filter_str = quote(filter_str, safe='')

# Construct the API URL
url = f'https://monitoring.googleapis.com/v3/projects/{project_id}/timeSeries?filter={encoded_filter_str}&interval.startTime={start_time.strftime("%Y-%m-%dT%H:%M:%SZ")}&interval.endTime={new_end_time}'
print('url')

print(url)

# Get the access token
token = "ya29.c.c0AY_VpZiWweZFp26Dkz4nDO35TGTR5UELrBhLwCnovFESiqFFvYf8raJxqAg3qxZTUCgvt80RsQr1xtWIVb8y1Xzy85-uPJP_yuzYcfu2lxMeLDn4HwU6-GFZaPxhzlvNrdkSNi9K8CEQYcnszsqIONwg_QZ4lRhRyD_7KR8K4ACxjigV2SxBJP4gWXw1wliO2zs8EE5X5iWjA51NWLuz4c-aVKQwflBpqG5dRoCLBDb1b4j3WKVBxFEjzcefsAC1C0wlGULrrFvX1kLbduMSpST_6Cosc3aViHUWAZrT-GbcOubBBHTtWmz9uIpSigCrB2AeT3Hkhz8US55ZHzWbbElG0NFripfFb-Mc1NZQXMHxqABkWYy2L9od8RQMC3j9E8UMp0qrion8EJj-IBTALPq97Yt9jHsPSuJjEUY3b8ZMCLZ4j6r_mVtao9r0vokqfPl5DEuCLWKnI9JfMkk_aayC8tltn3BLLs1GTkUdXqjFVrtz9MrjKhXiT9HNEdJgcePEUrVP20eSf0BCbVsCKN-FdvKiTIKqGD8t1cK97uAiujexku1VBGTfCaEGkA5OuAE0o66k_qUanatgeCFgZLz859-AXaYhWgU-zUszT625K6Mj6eMrx95wn4c_U4ZOrSyehg8zxfmaBIJuBZ_6wQ2R7n6k7fYQB-k0Bdiyl0qxy-B7r9Rdm2tuz1v9vjmFid_xmzyf216_a8fMmqx45jkmI8wtZX0UsmrRXRfSm_oSc2YMm3SJx-2p4sIpQ-hzbe-YYymzmFUcwlrt66cYcoss8zsiFzYBiVIBUI6XgxBp-I8BwY3rOjBher1JXjY4uIflVOZpbff6_Shs82e4isQ0nzy0XopVRgdhvpcB1losO9fYUn9nVy16vjQsVlqQw5W6bM62r_zhwpOvyy90MZVcJBMVJU4W1tvxwfrXJJXVvBz_2t2loOj0w35m5x4WsvUrX4c1lo0ohbhbyp1W7caUyfiUQzi2eleQrRXbqke10aIeSW0rew6"


response = requests.get(
    url,
    headers={"Authorization": f"Bearer {token}"}
)

# Print the response
print(response.json())
# Out:
# end_time 2024-03-28 05:09:54.089903
# new_end_time 2024-03-28T05:09:54Z
# url
# https://monitoring.googleapis.com/v3/projects/fdc-development-408605/timeSeries?filter=resource.type%3D%22k8s_pod%22%20AND%20resource.label.%22pod_name%22%3D%22jy-75276912-5911-41bc-a7d2-22787407cc5c-sunny10683796ltimindt%22%20AND%20metric.type%3D%22kubernetes.io%2Fcontainer%2Fcpu%2Fusage%22&interval.startTime=2024-03-28T03:09:54Z&interval.endTime=2024-03-28T05:09:54Z
# {'error': {'code': 404, 'message': 'Cannot find metric(s) that match type = "kubernetes.io/container/cpu/usage". If a metric was created recently, it could take up to 10 minutes to become available. Please try again soon.', 'status': 'NOT_FOUND'}}

# %%
import google.auth
import requests
from datetime import datetime, timedelta
from urllib.parse import quote

def fetch_pod_resources(pod_name):
    # Here you should fetch the total CPU and memory resources allocated to the pod
    # This could be obtained from Kubernetes API or any other source you're using to manage your pods
    # For demonstration purposes, I'll assume you have a function to fetch these values
    total_cpu = 1.0  # Placeholder value for demonstration
    total_memory = 1024  # Placeholder value in MB for demonstration
    return total_cpu, total_memory

def calculate_percentage_utilization(cpu_used, memory_used, total_cpu, total_memory):
    cpu_percent = (cpu_used / total_cpu) * 100
    memory_percent = (memory_used / total_memory) * 100
    return cpu_percent, memory_percent

# Define the project ID
project_id = "fdc-development-408605"

# Define the current time and interval
end_time = datetime.utcnow()
start_time = end_time - timedelta(hours=2)
print("end_time", end_time)
new_end_time = end_time.strftime("%Y-%m-%dT%H:%M:%SZ")
print("new_end_time", new_end_time)

# Define filter string
filter_str = 'resource.type="k8s_container" AND resource.label."pod_name"="jy-187dde38-743d-49fb-b339-236a6c1413ee-sunny10683796ltimindt" AND metric.type="kubernetes.io/container/cpu/limit_utilization"'
encoded_filter_str = quote(filter_str, safe='')

# Construct the API URL
url = f'https://monitoring.googleapis.com/v3/projects/{project_id}/timeSeries?filter={encoded_filter_str}&interval.startTime={start_time.strftime("%Y-%m-%dT%H:%M:%SZ")}&interval.endTime={new_end_time}'

# Get the access token
token = "ya29.c.c0AY_VpZiWweZFp26Dkz4nDO35TGTR5UELrBhLwCnovFESiqFFvYf8raJxqAg3qxZTUCgvt80RsQr1xtWIVb8y1Xzy85-uPJP_yuzYcfu2lxMeLDn4HwU6-GFZaPxhzlvNrdkSNi9K8CEQYcnszsqIONwg_QZ4lRhRyD_7KR8K4ACxjigV2SxBJP4gWXw1wliO2zs8EE5X5iWjA51NWLuz4c-aVKQwflBpqG5dRoCLBDb1b4j3WKVBxFEjzcefsAC1C0wlGULrrFvX1kLbduMSpST_6Cosc3aViHUWAZrT-GbcOubBBHTtWmz9uIpSigCrB2AeT3Hkhz8US55ZHzWbbElG0NFripfFb-Mc1NZQXMHxqABkWYy2L9od8RQMC3j9E8UMp0qrion8EJj-IBTALPq97Yt9jHsPSuJjEUY3b8ZMCLZ4j6r_mVtao9r0vokqfPl5DEuCLWKnI9JfMkk_aayC8tltn3BLLs1GTkUdXqjFVrtz9MrjKhXiT9HNEdJgcePEUrVP20eSf0BCbVsCKN-FdvKiTIKqGD8t1cK97uAiujexku1VBGTfCaEGkA5OuAE0o66k_qUanatgeCFgZLz859-AXaYhWgU-zUszT625K6Mj6eMrx95wn4c_U4ZOrSyehg8zxfmaBIJuBZ_6wQ2R7n6k7fYQB-k0Bdiyl0qxy-B7r9Rdm2tuz1v9vjmFid_xmzyf216_a8fMmqx45jkmI8wtZX0UsmrRXRfSm_oSc2YMm3SJx-2p4sIpQ-hzbe-YYymzmFUcwlrt66cYcoss8zsiFzYBiVIBUI6XgxBp-I8BwY3rOjBher1JXjY4uIflVOZpbff6_Shs82e4isQ0nzy0XopVRgdhvpcB1losO9fYUn9nVy16vjQsVlqQw5W6bM62r_zhwpOvyy90MZVcJBMVJU4W1tvxwfrXJJXVvBz_2t2loOj0w35m5x4WsvUrX4c1lo0ohbhbyp1W7caUyfiUQzi2eleQrRXbqke10aIeSW0rew6"

# Make the API call
response = requests.get(
    url,
    headers={"Authorization": f"Bearer {token}"}
)
pod_name= "jy-75276912-5911-41bc-a7d2-22787407cc5c-sunny10683796ltimindt"
# Check if the response is successful
if response.status_code == 200:
    # Parse the response JSON
    data = response.json()

    # Initialize variables for CPU and memory usage
    cpu_usage_total = 0
    memory_usage_total = 0

    print('dataaa')
    print(data)
    
    # Iterate over the time series data
    for time_series in data.get('timeSeries', []):
        # Iterate over the data points in each time series
        for point in time_series.get('points', []):
            # Extract the value from the data point if it exists
            value = point.get('value', {}).get('doubleValue', None)
            
            print('each val')
            print(value)
            if value is not None:
                # Add the value to the total CPU or memory usage
                if time_series['metric']['type'] == 'kubernetes.io/container/cpu/limit_utilization':
                    cpu_usage_total += value
                elif time_series['metric']['type'] == 'kubernetes.io/container/memory/limit_utilization':
                    memory_usage_total += value

    # Fetch the total CPU and memory resources allocated to the pod
    total_cpu, total_memory = fetch_pod_resources(pod_name)
    print('total usage')
    print(cpu_usage_total)
    # Calculate the percentage utilization
    cpu_percent, memory_percent = calculate_percentage_utilization(cpu_usage_total, memory_usage_total, total_cpu, total_memory)

    # Print or return the results as needed
    print("CPU Percentage Utilization:", cpu_percent)
    print("Memory Percentage Utilization:", memory_percent)
else:
    print("Error:", response.text)
# Out:
# end_time 2024-03-28 05:09:33.214072
# new_end_time 2024-03-28T05:09:33Z
# dataaa
# {'unit': '1'}
# total usage
# 0
# CPU Percentage Utilization: 0.0
# Memory Percentage Utilization: 0.0
