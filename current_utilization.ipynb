# %%
# !curl -H "Metadata-Flavor: Google" http://169.254.169.254/computeMetadata/v1/instance/service-accounts/default/token
# Out:
# {"access_token":"ya29.c.c0AY_VpZiH0DOrCojyZGF_SmqS6dp6TyDIwg5IKLUWtFgUXpwxi6duKQ5i3-P5ddgM8_qyjDdCLX7S67as83FzaSe8Ew-49fsOTzupuR2jsjyVgIGhk32-ncZweaxCiLzLvza5R_dobN0L5cUbmR1zsKzBZtV3sr3OmxL7iN2qZG7X4rW3rcP44oiYewO04ItZUJuMToJa9yJSc0siGtyYELx9kfJQzeMS6jCxL3E8bYKP3TMIiIwlkgcx_kW5PvhbWsp8s1o9wltZTAiqrGCKD8dcuDeKVSdRTofvnWd7fqxJKoshc6wPFHEje7ZBcbU4JAtL4W9a16crphQf4M_HMdm6UNDqVvt4cyylVIwy9mZklQh6sHyrvR8llxtVsZj2Q0nKPpOgz_U508MlBvBE4AecQOGdFMXn1cEbeu6EhASIsCVHGhLv3r-o56zZMyP_-yFxIBBg7rRGvTCFnjwxuIt4oeMAWrLcVWUczG1EqBCI4RNN0EJzPgpzrctX01HvirKnUt88wcePAEXudKjx4R5LS-ZxeOmuXpjTt5LFn7gTikNX00o3mGHsm0BUElh2j04qpxbB9UHx8fV_tapGPHsSbrCaE16JSIqFaB6wAAN627DVB41M98aF3RM_1mf4unljhcOyx14ltofh4WurzwlIVwtr0mJqm7qde_og0WZFV_Su72zw6-Zr5ayO_cR9hIIh_5Fdx8IuBZob5Y2B4UztafOfQtsMke9emYdbXeyIynoxbMjFF5I0Z4kzmZngURe3-sbiptxrynSw4e0F3JWImw8FO6Q2y_YWB234ptM8Q-OzB7JpWSe8aXiZvXIyWRRoBW0sRW7rzFUsrO_2kXcSno-Wu9ImBO3-MZJq1Ff2m3VbfQ9Blp9663YroJgS-2ajal_h_lFzgmZO3WY78tmrFyp8Q58-9fg0hJbhf7s3lyR7tq9hV3ZZJ-r4oWpFxhYUVWzVymJVQMftBmOpZJsp1Oc3vlUx3nh2o5vvXnwfYdnUh3_f655","expires_in":3599,"token_type":"Bearer"}

# %%
import google.auth
import requests
from datetime import datetime, timedelta
from urllib.parse import quote

# # Get credentials
# credentials, _ = google.auth.default(scopes=["https://www.googleapis.com/auth/cloud-platform"])
# print('ss')
# print(credentials)
# print('ss')

# Define the project ID
project_id = "fdc-development-408605"

# Define the current time and interval
end_time = datetime.utcnow()
start_time = end_time - timedelta(hours=2)
print("end_time", end_time)
new_end_time = end_time.strftime("%Y-%m-%dT%H:%M:%SZ")
print("new_end_time", new_end_time)

# Define filter string
filter_str = 'resource.type="k8s_pod" AND resource.label."pod_name"="jy-cd057557-24e2-4372-8016-be691a0ff67a-sunny10683796ltimindt" AND metric.type="kubernetes.io/container/cpu/usage"'
encoded_filter_str = quote(filter_str, safe='')

# Construct the API URL
url = f'https://monitoring.googleapis.com/v3/projects/{project_id}/timeSeries?filter={encoded_filter_str}&interval.startTime={start_time.strftime("%Y-%m-%dT%H:%M:%SZ")}&interval.endTime={new_end_time}'
print('url')

print(url)

# Get the access token
token = "ya29.c.c0AY_VpZiH0DOrCojyZGF_SmqS6dp6TyDIwg5IKLUWtFgUXpwxi6duKQ5i3-P5ddgM8_qyjDdCLX7S67as83FzaSe8Ew-49fsOTzupuR2jsjyVgIGhk32-ncZweaxCiLzLvza5R_dobN0L5cUbmR1zsKzBZtV3sr3OmxL7iN2qZG7X4rW3rcP44oiYewO04ItZUJuMToJa9yJSc0siGtyYELx9kfJQzeMS6jCxL3E8bYKP3TMIiIwlkgcx_kW5PvhbWsp8s1o9wltZTAiqrGCKD8dcuDeKVSdRTofvnWd7fqxJKoshc6wPFHEje7ZBcbU4JAtL4W9a16crphQf4M_HMdm6UNDqVvt4cyylVIwy9mZklQh6sHyrvR8llxtVsZj2Q0nKPpOgz_U508MlBvBE4AecQOGdFMXn1cEbeu6EhASIsCVHGhLv3r-o56zZMyP_-yFxIBBg7rRGvTCFnjwxuIt4oeMAWrLcVWUczG1EqBCI4RNN0EJzPgpzrctX01HvirKnUt88wcePAEXudKjx4R5LS-ZxeOmuXpjTt5LFn7gTikNX00o3mGHsm0BUElh2j04qpxbB9UHx8fV_tapGPHsSbrCaE16JSIqFaB6wAAN627DVB41M98aF3RM_1mf4unljhcOyx14ltofh4WurzwlIVwtr0mJqm7qde_og0WZFV_Su72zw6-Zr5ayO_cR9hIIh_5Fdx8IuBZob5Y2B4UztafOfQtsMke9emYdbXeyIynoxbMjFF5I0Z4kzmZngURe3-sbiptxrynSw4e0F3JWImw8FO6Q2y_YWB234ptM8Q-OzB7JpWSe8aXiZvXIyWRRoBW0sRW7rzFUsrO_2kXcSno-Wu9ImBO3-MZJq1Ff2m3VbfQ9Blp9663YroJgS-2ajal_h_lFzgmZO3WY78tmrFyp8Q58-9fg0hJbhf7s3lyR7tq9hV3ZZJ-r4oWpFxhYUVWzVymJVQMftBmOpZJsp1Oc3vlUx3nh2o5vvXnwfYdnUh3_f655"


response = requests.get(
    url,
    headers={"Authorization": f"Bearer {token}"}
)

# Print the response
print(response.json())
# Out:
# end_time 2024-03-27 16:55:55.168930
# new_end_time 2024-03-27T16:55:55Z
# url
# https://monitoring.googleapis.com/v3/projects/fdc-development-408605/timeSeries?filter=resource.type%3D%22k8s_container%22%20AND%20resource.label.%22pod_name%22%3D%22jy-187dde38-743d-49fb-b339-236a6c1413ee-sunny10683796ltimindt%22%20AND%20metric.type%3D%22kubernetes.io%2Fcontainer%2Fcpu%2Flimit_utilization%22&interval.startTime=2024-03-27T14:55:55Z&interval.endTime=2024-03-27T16:55:55Z
# {'timeSeries': [{'metric': {'type': 'kubernetes.io/container/cpu/limit_utilization'}, 'resource': {'type': 'k8s_container', 'labels': {'namespace_name': 'insight', 'project_id': 'fdc-development-408605', 'cluster_name': 'fdc-development-01', 'location': 'us-central1-a', 'container_name': 'knights-watch', 'pod_name': 'jy-187dde38-743d-49fb-b339-236a6c1413ee-sunny10683796ltimindt'}}, 'metricKind': 'GAUGE', 'valueType': 'DOUBLE', 'points': [{'interval': {'startTime': '2024-03-27T16:53:00Z', 'endTime': '2024-03-27T16:53:00Z'}, 'value': {'doubleValue': 0.003069116311582176}}, {'interval': {'startTime': '2024-03-27T16:52:00Z', 'endTime': '2024-03-27T16:52:00Z'}, 'value': {'doubleValue': 0.0033418165419221452}}, {'interval': {'startTime': '2024-03-27T16:51:00Z', 'endTime': '2024-03-27T16:51:00Z'}, 'value': {'doubleValue': 0.003895611969845595}}, {'interval': {'startTime': '2024-03-27T16:50:00Z', 'endTime': '2024-03-27T16:50:00Z'}, 'value': {'doubleValue': 0.0035648288753118724}}, {'interval': {'startTime': '2024-03-27T16:49:00Z', 'endTime': '2024-03-27T16:49:00Z'}, 'value': {'doubleValue': 0.0034818038977636394}}, {'interval': {'startTime': '2024-03-27T16:48:00Z', 'endTime': '2024-03-27T16:48:00Z'}, 'value': {'doubleValue': 0.0031133004056985714}}, {'interval': {'startTime': '2024-03-27T16:47:00Z', 'endTime': '2024-03-27T16:47:00Z'}, 'value': {'doubleValue': 0.0032912726550051283}}, {'interval': {'startTime': '2024-03-27T16:46:00Z', 'endTime': '2024-03-27T16:46:00Z'}, 'value': {'doubleValue': 0.0033713887340702203}}, {'interval': {'startTime': '2024-03-27T16:45:00Z', 'endTime': '2024-03-27T16:45:00Z'}, 'value': {'doubleValue': 0.0032681041939916313}}, {'interval': {'startTime': '2024-03-27T16:44:00Z', 'endTime': '2024-03-27T16:44:00Z'}, 'value': {'doubleValue': 0.004030828179418473}}, {'interval': {'startTime': '2024-03-27T16:43:00Z', 'endTime': '2024-03-27T16:43:00Z'}, 'value': {'doubleValue': 0.003937072878761305}}, {'interval': {'startTime': '2024-03-27T16:42:00Z', 'endTime': '2024-03-27T16:42:00Z'}, 'value': {'doubleValue': 0.003963685122924043}}, {'interval': {'startTime': '2024-03-27T16:41:00Z', 'endTime': '2024-03-27T16:41:00Z'}, 'value': {'doubleValue': 0.003824222735459411}}, {'interval': {'startTime': '2024-03-27T16:40:00Z', 'endTime': '2024-03-27T16:40:00Z'}, 'value': {'doubleValue': 0.003970181430776639}}, {'interval': {'startTime': '2024-03-27T16:39:00Z', 'endTime': '2024-03-27T16:39:00Z'}, 'value': {'doubleValue': 0.003623318109585449}}, {'interval': {'startTime': '2024-03-27T16:38:00Z', 'endTime': '2024-03-27T16:38:00Z'}, 'value': {'doubleValue': 0.0032436578077984315}}, {'interval': {'startTime': '2024-03-27T16:37:00Z', 'endTime': '2024-03-27T16:37:00Z'}, 'value': {'doubleValue': 0.003975666732837905}}, {'interval': {'startTime': '2024-03-27T16:36:00Z', 'endTime': '2024-03-27T16:36:00Z'}, 'value': {'doubleValue': 0.0037928798316017847}}, {'interval': {'startTime': '2024-03-27T16:35:00Z', 'endTime': '2024-03-27T16:35:00Z'}, 'value': {'doubleValue': 0.013566200010499189}}]}, {'metric': {'type': 'kubernetes.io/container/cpu/limit_utilization'}, 'resource': {'type': 'k8s_container', 'labels': {'pod_name': 'jy-187dde38-743d-49fb-b339-236a6c1413ee-sunny10683796ltimindt', 'location': 'us-central1-a', 'namespace_name': 'insight', 'cluster_name': 'fdc-development-01', 'container_name': 'notebooks', 'project_id': 'fdc-development-408605'}}, 'metricKind': 'GAUGE', 'valueType': 'DOUBLE', 'points': [{'interval': {'startTime': '2024-03-27T16:53:00Z', 'endTime': '2024-03-27T16:53:00Z'}, 'value': {'doubleValue': 0.00032845746739785484}}, {'interval': {'startTime': '2024-03-27T16:52:00Z', 'endTime': '2024-03-27T16:52:00Z'}, 'value': {'doubleValue': 0.00028196031147531287}}, {'interval': {'startTime': '2024-03-27T16:51:00Z', 'endTime': '2024-03-27T16:51:00Z'}, 'value': {'doubleValue': 0.00029337039012660213}}, {'interval': {'startTime': '2024-03-27T16:50:00Z', 'endTime': '2024-03-27T16:50:00Z'}, 'value': {'doubleValue': 0.0006112699646 ...

# %%
import google.auth
import requests
from datetime import datetime, timedelta
from urllib.parse import quote

def fetch_pod_resources(pod_name):
    # Here you should fetch the total CPU and memory resources allocated to the pod
    # This could be obtained from Kubernetes API or any other source you're using to manage your pods
    # For demonstration purposes, I'll assume you have a function to fetch these values
    total_cpu = 1.0  # Placeholder value for demonstration
    total_memory = 1024  # Placeholder value in MB for demonstration
    return total_cpu, total_memory

def calculate_percentage_utilization(cpu_used, memory_used, total_cpu, total_memory):
    cpu_percent = (cpu_used / total_cpu) * 100
    memory_percent = (memory_used / total_memory) * 100
    return cpu_percent, memory_percent

# Define the project ID
project_id = "fdc-development-408605"

# Define the current time and interval
end_time = datetime.utcnow()
start_time = end_time - timedelta(hours=2)
print("end_time", end_time)
new_end_time = end_time.strftime("%Y-%m-%dT%H:%M:%SZ")
print("new_end_time", new_end_time)

# Define filter string
filter_str = 'resource.type="k8s_container" AND resource.label."pod_name"="jy-187dde38-743d-49fb-b339-236a6c1413ee-sunny10683796ltimindt" AND metric.type="kubernetes.io/container/cpu/limit_utilization"'
encoded_filter_str = quote(filter_str, safe='')

# Construct the API URL
url = f'https://monitoring.googleapis.com/v3/projects/{project_id}/timeSeries?filter={encoded_filter_str}&interval.startTime={start_time.strftime("%Y-%m-%dT%H:%M:%SZ")}&interval.endTime={new_end_time}'

# Get the access token
token = "ya29.c.c0AY_VpZiH0DOrCojyZGF_SmqS6dp6TyDIwg5IKLUWtFgUXpwxi6duKQ5i3-P5ddgM8_qyjDdCLX7S67as83FzaSe8Ew-49fsOTzupuR2jsjyVgIGhk32-ncZweaxCiLzLvza5R_dobN0L5cUbmR1zsKzBZtV3sr3OmxL7iN2qZG7X4rW3rcP44oiYewO04ItZUJuMToJa9yJSc0siGtyYELx9kfJQzeMS6jCxL3E8bYKP3TMIiIwlkgcx_kW5PvhbWsp8s1o9wltZTAiqrGCKD8dcuDeKVSdRTofvnWd7fqxJKoshc6wPFHEje7ZBcbU4JAtL4W9a16crphQf4M_HMdm6UNDqVvt4cyylVIwy9mZklQh6sHyrvR8llxtVsZj2Q0nKPpOgz_U508MlBvBE4AecQOGdFMXn1cEbeu6EhASIsCVHGhLv3r-o56zZMyP_-yFxIBBg7rRGvTCFnjwxuIt4oeMAWrLcVWUczG1EqBCI4RNN0EJzPgpzrctX01HvirKnUt88wcePAEXudKjx4R5LS-ZxeOmuXpjTt5LFn7gTikNX00o3mGHsm0BUElh2j04qpxbB9UHx8fV_tapGPHsSbrCaE16JSIqFaB6wAAN627DVB41M98aF3RM_1mf4unljhcOyx14ltofh4WurzwlIVwtr0mJqm7qde_og0WZFV_Su72zw6-Zr5ayO_cR9hIIh_5Fdx8IuBZob5Y2B4UztafOfQtsMke9emYdbXeyIynoxbMjFF5I0Z4kzmZngURe3-sbiptxrynSw4e0F3JWImw8FO6Q2y_YWB234ptM8Q-OzB7JpWSe8aXiZvXIyWRRoBW0sRW7rzFUsrO_2kXcSno-Wu9ImBO3-MZJq1Ff2m3VbfQ9Blp9663YroJgS-2ajal_h_lFzgmZO3WY78tmrFyp8Q58-9fg0hJbhf7s3lyR7tq9hV3ZZJ-r4oWpFxhYUVWzVymJVQMftBmOpZJsp1Oc3vlUx3nh2o5vvXnwfYdnUh3_f655"

# Make the API call
response = requests.get(
    url,
    headers={"Authorization": f"Bearer {token}"}
)
pod_name= "jy-187dde38-743d-49fb-b339-236a6c1413ee-sunny10683796ltimindt"
# Check if the response is successful
if response.status_code == 200:
    # Parse the response JSON
    data = response.json()

    # Initialize variables for CPU and memory usage
    cpu_usage_total = 0
    memory_usage_total = 0

    print('dataaa')
    print(data)
    
    # Iterate over the time series data
    for time_series in data.get('timeSeries', []):
        # Iterate over the data points in each time series
        for point in time_series.get('points', []):
            # Extract the value from the data point if it exists
            value = point.get('value', {}).get('doubleValue', None)
            
            print('each val')
            print(value)
            if value is not None:
                # Add the value to the total CPU or memory usage
                if time_series['metric']['type'] == 'kubernetes.io/container/cpu/limit_utilization':
                    cpu_usage_total += value
                elif time_series['metric']['type'] == 'kubernetes.io/container/memory/limit_utilization':
                    memory_usage_total += value

    # Fetch the total CPU and memory resources allocated to the pod
    total_cpu, total_memory = fetch_pod_resources(pod_name)
    print('total usage')
    print(cpu_usage_total)
    # Calculate the percentage utilization
    cpu_percent, memory_percent = calculate_percentage_utilization(cpu_usage_total, memory_usage_total, total_cpu, total_memory)

    # Print or return the results as needed
    print("CPU Percentage Utilization:", cpu_percent)
    print("Memory Percentage Utilization:", memory_percent)
else:
    print("Error:", response.text)
# Out:
# end_time 2024-03-27 17:10:56.257807
# new_end_time 2024-03-27T17:10:56Z
# dataaa
# {'timeSeries': [{'metric': {'type': 'kubernetes.io/container/cpu/limit_utilization'}, 'resource': {'type': 'k8s_container', 'labels': {'project_id': 'fdc-development-408605', 'pod_name': 'jy-187dde38-743d-49fb-b339-236a6c1413ee-sunny10683796ltimindt', 'container_name': 'knights-watch', 'cluster_name': 'fdc-development-01', 'location': 'us-central1-a', 'namespace_name': 'insight'}}, 'metricKind': 'GAUGE', 'valueType': 'DOUBLE', 'points': [{'interval': {'startTime': '2024-03-27T17:08:00Z', 'endTime': '2024-03-27T17:08:00Z'}, 'value': {'doubleValue': 0.0036660103750041804}}, {'interval': {'startTime': '2024-03-27T17:07:00Z', 'endTime': '2024-03-27T17:07:00Z'}, 'value': {'doubleValue': 0.002682097115483876}}, {'interval': {'startTime': '2024-03-27T17:06:00Z', 'endTime': '2024-03-27T17:06:00Z'}, 'value': {'doubleValue': 0.0031050589783300888}}, {'interval': {'startTime': '2024-03-27T17:05:00Z', 'endTime': '2024-03-27T17:05:00Z'}, 'value': {'doubleValue': 0.0039433457918016225}}, {'interval': {'startTime': '2024-03-27T17:04:00Z', 'endTime': '2024-03-27T17:04:00Z'}, 'value': {'doubleValue': 0.0035946804910803377}}, {'interval': {'startTime': '2024-03-27T17:03:00Z', 'endTime': '2024-03-27T17:03:00Z'}, 'value': {'doubleValue': 0.003026112840039537}}, {'interval': {'startTime': '2024-03-27T17:02:00Z', 'endTime': '2024-03-27T17:02:00Z'}, 'value': {'doubleValue': 0.0035183004398186817}}, {'interval': {'startTime': '2024-03-27T17:01:00Z', 'endTime': '2024-03-27T17:01:00Z'}, 'value': {'doubleValue': 0.0038042475610137404}}, {'interval': {'startTime': '2024-03-27T17:00:00Z', 'endTime': '2024-03-27T17:00:00Z'}, 'value': {'doubleValue': 0.003399646759222611}}, {'interval': {'startTime': '2024-03-27T16:59:00Z', 'endTime': '2024-03-27T16:59:00Z'}, 'value': {'doubleValue': 0.0030463643698573238}}, {'interval': {'startTime': '2024-03-27T16:58:00Z', 'endTime': '2024-03-27T16:58:00Z'}, 'value': {'doubleValue': 0.0032439742893430137}}, {'interval': {'startTime': '2024-03-27T16:57:00Z', 'endTime': '2024-03-27T16:57:00Z'}, 'value': {'doubleValue': 0.0027558142440720374}}, {'interval': {'startTime': '2024-03-27T16:56:00Z', 'endTime': '2024-03-27T16:56:00Z'}, 'value': {'doubleValue': 0.002894892128645384}}, {'interval': {'startTime': '2024-03-27T16:55:00Z', 'endTime': '2024-03-27T16:55:00Z'}, 'value': {'doubleValue': 0.003674079539309627}}, {'interval': {'startTime': '2024-03-27T16:54:00Z', 'endTime': '2024-03-27T16:54:00Z'}, 'value': {'doubleValue': 0.0031223204583166334}}, {'interval': {'startTime': '2024-03-27T16:53:00Z', 'endTime': '2024-03-27T16:53:00Z'}, 'value': {'doubleValue': 0.003069116311582176}}, {'interval': {'startTime': '2024-03-27T16:52:00Z', 'endTime': '2024-03-27T16:52:00Z'}, 'value': {'doubleValue': 0.0033418165419221452}}, {'interval': {'startTime': '2024-03-27T16:51:00Z', 'endTime': '2024-03-27T16:51:00Z'}, 'value': {'doubleValue': 0.003895611969845595}}, {'interval': {'startTime': '2024-03-27T16:50:00Z', 'endTime': '2024-03-27T16:50:00Z'}, 'value': {'doubleValue': 0.0035648288753118724}}, {'interval': {'startTime': '2024-03-27T16:49:00Z', 'endTime': '2024-03-27T16:49:00Z'}, 'value': {'doubleValue': 0.0034818038977636394}}, {'interval': {'startTime': '2024-03-27T16:48:00Z', 'endTime': '2024-03-27T16:48:00Z'}, 'value': {'doubleValue': 0.0031133004056985714}}, {'interval': {'startTime': '2024-03-27T16:47:00Z', 'endTime': '2024-03-27T16:47:00Z'}, 'value': {'doubleValue': 0.0032912726550051283}}, {'interval': {'startTime': '2024-03-27T16:46:00Z', 'endTime': '2024-03-27T16:46:00Z'}, 'value': {'doubleValue': 0.0033713887340702203}}, {'interval': {'startTime': '2024-03-27T16:45:00Z', 'endTime': '2024-03-27T16:45:00Z'}, 'value': {'doubleValue': 0.0032681041939916313}}, {'interval': {'startTime': '2024-03-27T16:44:00Z', 'endTime': '2024-03-27T16:44:00Z'}, 'value': {'doubleValue': 0.004030828179418473}}, {'interval': {'startTime': '2024-03-27T16:43:00Z', 'endTime': '2024-03-27T16:43:00Z'}, 'value': {'doubleValue': 0.003937072878761305}}, {'int ...
# each val
# 0.0036660103750041804
# each val
# 0.002682097115483876
# each val
# 0.0031050589783300888
# each val
# 0.0039433457918016225
# each val
# 0.0035946804910803377
# each val
# 0.003026112840039537
# each val
# 0.0035183004398186817
# each val
# 0.0038042475610137404
# each val
# 0.003399646759222611
# each val
# 0.0030463643698573238
# each val
# 0.0032439742893430137
# each val
# 0.0027558142440720374
# each val
# 0.002894892128645384
# each val
# 0.003674079539309627
# each val
# 0.0031223204583166334
# each val
# 0.003069116311582176
# each val
# 0.0033418165419221452
# each val
# 0.003895611969845595
# each val
# 0.0035648288753118724
# each val
# 0.0034818038977636394
# each val
# 0.0031133004056985714
# each val
# 0.0032912726550051283
# each val
# 0.0033713887340702203
# each val
# 0.0032681041939916313
# each val
# 0.004030828179418473
# each val
# 0.003937072878761305
# each val
# 0.003963685122924043
# each val
# 0.003824222735459411
# each val
# 0.003970181430776639
# each val
# 0.003623318109585449
# each val
# 0.0032436578077984315
# each val
# 0.003975666732837905
# each val
# 0.0037928798316017847
# each val
# 0.013566200010499189
# each val
# 0.0003133080944285459
# each val
# 0.0002965720040085239
# each val
# 0.0003020164752645898
# each val
# 0.000299273934996302
# each val
# 0.0003160657221207471
# each val
# 0.0003037617336883537
# each val
# 0.00029174972753718116
# each val
# 0.0003064072683242153
# each val
# 0.00031811986764675106
# each val
# 0.0002988044950999469
# each val
# 0.0003115274028375668
# each val
# 0.00029455508750128194
# each val
# 0.000278511143150671
# each val
# 0.0002945593330689624
# each val
# 0.0003109818228198769
# each val
# 0.00032845746739785484
# each val
# 0.00028196031147531287
# each val
# 0.00029337039012660213
# each val
# 0.0006112699646539457
# each val
# 0.0002584591472520299
# each val
# 0.0001971391062106484
# each val
# 0.00029631400011361934
# each val
# 0.00030658137663156876
# each val
# 0.00029527829440157387
# each val
# 0.000282996585824353
# each val
# 0.0002820701878309618
# each val
# 0.0003055507981575807
# each val
# 0.0003176703415341212
# each val
# 0.0003100729879950772
# each val
# 0.0002997879338239505
# each val
# 0.00028287907136080923
# each val
# 0.00042821632299899244
# each val
# 0.0006701065098925154
# each val
# 0.012316074578462323
# total usage
# 0.1507023712948296
# CPU Percentage Utilization: 15.07023712948296
# Memory Percentage Utilization: 0.0
