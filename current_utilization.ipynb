# %%
# !curl -H "Metadata-Flavor: Google" http://169.254.169.254/computeMetadata/v1/instance/service-accounts/default/token
# Out:
# {"access_token":"ya29.c.c0AY_VpZgFg1hgMSNNoS50CYxDdldUYyvxOOB9pKuU7KB-RXIVqiKX_oq7hPKmw-VU6sEb_tPE0luYJH-BBEhMv5-2tiZb2VF0Dy70NM7wKgK1xWSeOEUlr-piiC0u7FBKvd4GBdVAT7pGzcuhRfXoOIFIQXFvdnDnNX0WviDtdiga5eu4RnVGXIG-BI_NSwdNI6-g7VJMbK4MeKbWgauoc6I6hKjx6x4pOu7-NC4hFfD74wLNf0QtN8FQUeN45VvBR0YSnD-d6xBwSr1o4zE6libbkeVvBkl8GUnrM0aZIT0pT3CCgJu3GTzj3CdRLYEonY8W33LeKqMz1hSU8g9TRIAEBVFj-hmDrnhdV8DS8PkIjiaR0swQJA9uYJuuQezbh-BdJT1S9oGR9--oWM39z2VB7OyUPy1nM9x-ajfXFVfhe5BTl6nZMzZfnql6szrRjEuQz3QkJuI3Q-GXrCC_lKQW9jH_NMSfbw2moSMTVTSOcO_Z6amraR6amiIA5k2O4dIiNgen3Qd3eF3H4u6R6EyA5D1cCRAXu0kNV2SEJPBHXS85OuLkOo7gbjuo16_mc3RYRfr9eXh_vejJd6b6CMlXxGiJkkCTilf2EZgqUsAN628P_aZbrBXn45Icf-8lVtI4oRFzzMJr1k1lzobpxa_Upf87qOoXjIWoIxhn6g_6is-65UrvdIk6d3o6pvY0tFe7n-ZZwUIqjFmtZFQXo2nfmOlXmqcu9tlySpfrqsZeg92gesjxZ_2jq0WxByu0r00eF5w7ucpUxjXznxM_RtdQWWOYmgyXIsXO_fVIqteZxQW4mF5gfUFuzu9xjvk0vdJasJkVUwoxb1ftjIZ3l060xS_-j2MeYcqI_Su64Shh2bU75XlJJ-01vOIcMwh9jIwfUJ-2wI91xllm92teMhF1emUIM3Jldaw6yQzumS0Qgr-bveJxVkvI_J11dk18kzy7UiiX7g6zXv_ce6g67s1QZ5qwJzBX0Otodnt4zsvsU9xBR3bdUlf","expires_in":2548,"token_type":"Bearer"}

# %%
import google.auth
import requests
from datetime import datetime, timedelta
from urllib.parse import quote

project_id = "fdc-development-408605"

# Define the current time and interval
end_time = datetime.utcnow()
start_time = end_time - timedelta(hours=2)
print("end_time", end_time)
new_end_time = end_time.strftime("%Y-%m-%dT%H:%M:%SZ")
print("new_end_time", new_end_time)

# Define filter string
filter_str = 'resource.type="k8s_container" AND resource.label."pod_name"="jy-75276912-5911-41bc-a7d2-22787407cc5c-sunny10683796ltimindt" AND metric.type="kubernetes.io/container/cpu/limit_utilization"'
encoded_filter_str = quote(filter_str, safe='')

# Construct the API URL
url = f'https://monitoring.googleapis.com/v3/projects/{project_id}/timeSeries?filter={encoded_filter_str}&interval.startTime={start_time.strftime("%Y-%m-%dT%H:%M:%SZ")}&interval.endTime={new_end_time}'

print(url)

token = "ya29.c.c0AY_VpZgFg1hgMSNNoS50CYxDdldUYyvxOOB9pKuU7KB-RXIVqiKX_oq7hPKmw-VU6sEb_tPE0luYJH-BBEhMv5-2tiZb2VF0Dy70NM7wKgK1xWSeOEUlr-piiC0u7FBKvd4GBdVAT7pGzcuhRfXoOIFIQXFvdnDnNX0WviDtdiga5eu4RnVGXIG-BI_NSwdNI6-g7VJMbK4MeKbWgauoc6I6hKjx6x4pOu7-NC4hFfD74wLNf0QtN8FQUeN45VvBR0YSnD-d6xBwSr1o4zE6libbkeVvBkl8GUnrM0aZIT0pT3CCgJu3GTzj3CdRLYEonY8W33LeKqMz1hSU8g9TRIAEBVFj-hmDrnhdV8DS8PkIjiaR0swQJA9uYJuuQezbh-BdJT1S9oGR9--oWM39z2VB7OyUPy1nM9x-ajfXFVfhe5BTl6nZMzZfnql6szrRjEuQz3QkJuI3Q-GXrCC_lKQW9jH_NMSfbw2moSMTVTSOcO_Z6amraR6amiIA5k2O4dIiNgen3Qd3eF3H4u6R6EyA5D1cCRAXu0kNV2SEJPBHXS85OuLkOo7gbjuo16_mc3RYRfr9eXh_vejJd6b6CMlXxGiJkkCTilf2EZgqUsAN628P_aZbrBXn45Icf-8lVtI4oRFzzMJr1k1lzobpxa_Upf87qOoXjIWoIxhn6g_6is-65UrvdIk6d3o6pvY0tFe7n-ZZwUIqjFmtZFQXo2nfmOlXmqcu9tlySpfrqsZeg92gesjxZ_2jq0WxByu0r00eF5w7ucpUxjXznxM_RtdQWWOYmgyXIsXO_fVIqteZxQW4mF5gfUFuzu9xjvk0vdJasJkVUwoxb1ftjIZ3l060xS_-j2MeYcqI_Su64Shh2bU75XlJJ-01vOIcMwh9jIwfUJ-2wI91xllm92teMhF1emUIM3Jldaw6yQzumS0Qgr-bveJxVkvI_J11dk18kzy7UiiX7g6zXv_ce6g67s1QZ5qwJzBX0Otodnt4zsvsU9xBR3bdUlf"

response = requests.get(
    url,
    headers={"Authorization": f"Bearer {token}"}
)
print(response.json())
# Out:
# end_time 2024-03-28 07:26:51.036609
# new_end_time 2024-03-28T07:26:51Z
# https://monitoring.googleapis.com/v3/projects/fdc-development-408605/timeSeries?filter=resource.type%3D%22k8s_container%22%20AND%20resource.label.%22pod_name%22%3D%22jy-75276912-5911-41bc-a7d2-22787407cc5c-sunny10683796ltimindt%22%20AND%20metric.type%3D%22kubernetes.io%2Fcontainer%2Fcpu%2Flimit_utilization%22&interval.startTime=2024-03-28T05:26:51Z&interval.endTime=2024-03-28T07:26:51Z
# {'error': {'code': 401, 'message': 'Request had invalid authentication credentials. Expected OAuth 2 access token, login cookie or other valid authentication credential. See https://developers.google.com/identity/sign-in/web/devconsole-project.', 'status': 'UNAUTHENTICATED', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'ACCESS_TOKEN_EXPIRED', 'domain': 'googleapis.com', 'metadata': {'service': 'monitoring.googleapis.com', 'method': 'google.monitoring.v3.MetricService.ListTimeSeries'}}]}}

# %%
import google.auth
import requests
from datetime import datetime, timedelta
from urllib.parse import quote

pod_name = "jy-75276912-5911-41bc-a7d2-22787407cc5c-sunny10683796ltimindt"

def fetch_pod_resources(pod_name):
    # Here you should fetch the total CPU and memory resources allocated to the pod
    # This could be obtained from Kubernetes API or any other source you're using to manage your pods
    # For demonstration purposes, I'll assume you have a function to fetch these values
    total_cpu = 1.0  # Placeholder value for demonstration
    total_memory = 1024  # Placeholder value in MB for demonstration
    return total_cpu, total_memory


def calculate_percentage_utilization(cpu_used, memory_used, total_cpu, total_memory):
    cpu_percent = (cpu_used / total_cpu) * 100
    memory_percent = (memory_used / total_memory) * 100
    return cpu_percent, memory_percent


# Define the project ID
project_id = "fdc-development-408605"

end_time = datetime.utcnow()
start_time = end_time - timedelta(minutes=3)

print("end_time", end_time)
new_end_time = end_time.strftime("%Y-%m-%dT%H:%M:%SZ")
print("new_end_time", new_end_time)

# Define filter string
filter_str = 'resource.type="k8s_container" AND resource.label."pod_name"="jy-75276912-5911-41bc-a7d2-22787407cc5c-sunny10683796ltimindt" AND metric.type="kubernetes.io/container/cpu/limit_utilization"'
encoded_filter_str = quote(filter_str, safe='')

# Construct the API URL
url = f'https://monitoring.googleapis.com/v3/projects/{project_id}/timeSeries?filter={encoded_filter_str}&interval.startTime={start_time.strftime("%Y-%m-%dT%H:%M:%SZ")}&interval.endTime={new_end_time}'

# Get the access token
token = "ya29.c.c0AY_VpZgFg1hgMSNNoS50CYxDdldUYyvxOOB9pKuU7KB-RXIVqiKX_oq7hPKmw-VU6sEb_tPE0luYJH-BBEhMv5-2tiZb2VF0Dy70NM7wKgK1xWSeOEUlr-piiC0u7FBKvd4GBdVAT7pGzcuhRfXoOIFIQXFvdnDnNX0WviDtdiga5eu4RnVGXIG-BI_NSwdNI6-g7VJMbK4MeKbWgauoc6I6hKjx6x4pOu7-NC4hFfD74wLNf0QtN8FQUeN45VvBR0YSnD-d6xBwSr1o4zE6libbkeVvBkl8GUnrM0aZIT0pT3CCgJu3GTzj3CdRLYEonY8W33LeKqMz1hSU8g9TRIAEBVFj-hmDrnhdV8DS8PkIjiaR0swQJA9uYJuuQezbh-BdJT1S9oGR9--oWM39z2VB7OyUPy1nM9x-ajfXFVfhe5BTl6nZMzZfnql6szrRjEuQz3QkJuI3Q-GXrCC_lKQW9jH_NMSfbw2moSMTVTSOcO_Z6amraR6amiIA5k2O4dIiNgen3Qd3eF3H4u6R6EyA5D1cCRAXu0kNV2SEJPBHXS85OuLkOo7gbjuo16_mc3RYRfr9eXh_vejJd6b6CMlXxGiJkkCTilf2EZgqUsAN628P_aZbrBXn45Icf-8lVtI4oRFzzMJr1k1lzobpxa_Upf87qOoXjIWoIxhn6g_6is-65UrvdIk6d3o6pvY0tFe7n-ZZwUIqjFmtZFQXo2nfmOlXmqcu9tlySpfrqsZeg92gesjxZ_2jq0WxByu0r00eF5w7ucpUxjXznxM_RtdQWWOYmgyXIsXO_fVIqteZxQW4mF5gfUFuzu9xjvk0vdJasJkVUwoxb1ftjIZ3l060xS_-j2MeYcqI_Su64Shh2bU75XlJJ-01vOIcMwh9jIwfUJ-2wI91xllm92teMhF1emUIM3Jldaw6yQzumS0Qgr-bveJxVkvI_J11dk18kzy7UiiX7g6zXv_ce6g67s1QZ5qwJzBX0Otodnt4zsvsU9xBR3bdUlf"

# Make the API call
response = requests.get(
    url,
    headers={"Authorization": f"Bearer {token}"}
)
# Check if the response is successful
if response.status_code == 200:
    # Parse the response JSON
    data = response.json()

    # Initialize variables for CPU and memory usage
    cpu_usage_total = 0
    memory_usage_total = 0

    print('dataaa')
    print(data)

    # Iterate over the time series data
    for time_series in data.get('timeSeries', []):
        # Iterate over the data points in each time series
        for point in time_series.get('points', []):
            # Extract the value from the data point if it exists
            value = point.get('value', {}).get('doubleValue', None)

            print('each val')
            print(value)
            if value is not None:
                # Add the value to the total CPU or memory usage
                if time_series['metric']['type'] == 'kubernetes.io/container/cpu/limit_utilization':
                    cpu_usage_total += value
                elif time_series['metric']['type'] == 'kubernetes.io/container/memory/limit_utilization':
                    memory_usage_total += value

    # Fetch the total CPU and memory resources allocated to the pod
    total_cpu, total_memory = fetch_pod_resources(pod_name)
    print('total usage')
    print(cpu_usage_total)
    # Calculate the percentage utilization
    cpu_percent, memory_percent = calculate_percentage_utilization(cpu_usage_total, memory_usage_total, total_cpu,
                                                                   total_memory)

    # Print or return the results as needed
    print("CPU Percentage Utilization:", cpu_percent)
    print("Memory Percentage Utilization:", memory_percent)
else:
    print("Error:", response.text)
# Out:
# end_time 2024-03-28 06:21:45.910507
# new_end_time 2024-03-28T06:21:45Z
# dataaa
# {'timeSeries': [{'metric': {'type': 'kubernetes.io/container/cpu/limit_utilization'}, 'resource': {'type': 'k8s_container', 'labels': {'pod_name': 'jy-75276912-5911-41bc-a7d2-22787407cc5c-sunny10683796ltimindt', 'container_name': 'knights-watch', 'namespace_name': 'insight', 'location': 'us-central1-a', 'cluster_name': 'fdc-development-01', 'project_id': 'fdc-development-408605'}}, 'metricKind': 'GAUGE', 'valueType': 'DOUBLE', 'points': [{'interval': {'startTime': '2024-03-28T06:19:00Z', 'endTime': '2024-03-28T06:19:00Z'}, 'value': {'doubleValue': 0.0004151174806839168}}]}, {'metric': {'type': 'kubernetes.io/container/cpu/limit_utilization'}, 'resource': {'type': 'k8s_container', 'labels': {'namespace_name': 'insight', 'project_id': 'fdc-development-408605', 'location': 'us-central1-a', 'pod_name': 'jy-75276912-5911-41bc-a7d2-22787407cc5c-sunny10683796ltimindt', 'container_name': 'notebooks', 'cluster_name': 'fdc-development-01'}}, 'metricKind': 'GAUGE', 'valueType': 'DOUBLE', 'points': [{'interval': {'startTime': '2024-03-28T06:19:00Z', 'endTime': '2024-03-28T06:19:00Z'}, 'value': {'doubleValue': 2.12222957392459e-05}}]}], 'unit': '1'}
# each val
# 0.0004151174806839168
# each val
# 2.12222957392459e-05
# total usage
# 0.0004363397764231627
# CPU Percentage Utilization: 0.04363397764231627
# Memory Percentage Utilization: 0.0

# %%
print('1')
# Out:
# 1
